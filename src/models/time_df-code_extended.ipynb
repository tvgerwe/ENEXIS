# %% [markdown]
# # refinement with "bank holidays" and (bouwvak) vakanties...
#
# Twan: holidays library takes official (NL) holidays. some holidays potentially associated with lower electricy load (TBC) are missing:
# Goede Vrijdag 15-04-2022, 07-04-2023, 29-03-2024, (18-04-2025)
# (vrij)daags na Hemelvaartsdag 27-05-2022, 19-05-2023, 10-05-2024
#
# in below code, bouwvak vakanties, local timezone and DST are added entities!!
#
# 28 April 2025: binomial variables like dst, weeknd, holiday, non_work_day and bouwvak have been changed to boolean.
# month_sin and month_cos are taken out (non constant cycle) and a sin/cos version of day of the year is added, dealing with leap years by dividing dayofheyear by 365.25 (days).
#
# TO DO: CONSIDER THE FOLLOWING CODE (CHATGPT SUGGESTED):
# df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
# df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
#
# df['dayofyear_sin'] = np.sin(2 * np.pi * df['dayofyear'] / 365)
# df['dayofyear_cos'] = np.cos(2 * np.pi * df['dayofyear'] / 365)

# %%
import pandas as pd
import numpy as np
import holidays
from datetime import date

# Genereer tijdstempel per uur tussen 2022 en 2024 (UTC)
time_df = pd.DataFrame({
    "datetime": pd.date_range("2022-01-01", "2024-12-31", freq="h", tz="UTC")
})

# Basis tijdkolommen
time_df["hour"] = time_df["datetime"].dt.hour
time_df["weekday"] = time_df["datetime"].dt.weekday  # Maandag = 0, Zondag = 6
time_df["month"] = time_df["datetime"].dt.month
time_df["date"] = time_df["datetime"].dt.date  # Nodig voor holiday lookup

# Cyclical encoding, only for cycles with same length. months are therefore excluded
time_df["hour_sin"] = np.sin(2 * np.pi * time_df["hour"] / 24)
time_df["hour_cos"] = np.cos(2 * np.pi * time_df["hour"] / 24)
time_df["weekday_sin"] = np.sin(2 * np.pi * time_df["weekday"] / 7)
time_df["weekday_cos"] = np.cos(2 * np.pi * time_df["weekday"] / 7)


# Convert from UTC to a local timezone (e.g., Europe/Amsterdam) to capture DST changes
time_df["local_datetime"] = time_df["datetime"].dt.tz_convert("Europe/Amsterdam")

# Get DST info and convert to boolean
time_df["is_dst"] = time_df["local_datetime"].apply(lambda x: int(x.dst() != pd.Timedelta(0))).astype('bool')

# Flags
# Weekend = Zaterdag (5) of Zondag (6)
time_df["is_weekend"] = time_df["weekday"].isin([5, 6]).astype('bool')

# Nationale feestdagen Nederland
nl_holidays = holidays.country_holidays("NL", years=[2022, 2023, 2024])
time_df["is_holiday"] = time_df["date"].isin(nl_holidays).astype('bool')

# Combinatie: niet-werkdag
time_df["is_non_working_day"] = ((time_df["is_weekend"] == 1) | (time_df["is_holiday"] == 1)).astype('bool')

# Startdata van de bouwvak per jaar
bouwvak_start = [
    date(2022, 7, 25),
    date(2023, 7, 22),
    date(2024, 7, 22),
    
] # date(2025, 7, 21), date(2026, 7, 18), date(2027, 7, 24), date(2028, 7, 22), date(2029, 7, 21) are further start dates

# Einddata van de bouwvak per jaar
bouwvak_end = [
    date(2022, 8, 26),
    date(2023, 8, 26),
    date(2024, 8, 23),
] # date(2025, 8, 22), date(2026, 8, 22), date(2027, 8, 29), date(2028, 8, 27), date(2029, 8, 24) further end dates

def is_bouwvak(d):
    return any(start <= d <= end for start, end in zip(bouwvak_start, bouwvak_end))

time_df['is_bouwvak'] = time_df['date'].apply(is_bouwvak).astype('bool')

# %%
# Add yearly sin/cos features
time_df["year"] = time_df["datetime"].dt.year
time_df["day_of_year"] = (time_df["datetime"].dt.strftime('%j').astype(int))  # Day of the year
time_df["yearly_sin"] = np.sin(2 * np.pi * time_df["day_of_year"] / 365.25)
time_df["yearly_cos"] = np.cos(2 * np.pi * time_df["day_of_year"] / 365.25)

# Drop redundant features and unnecessary columns
time_df.drop(["hour", "day_of_year", "weekday", "local_datetime"], axis=1, inplace=True)

# %%
print(time_df.info())
print(time_df.describe())
print(time_df.head(24))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            26281 non-null  datetime64[ns, UTC]
#  1   month               26281 non-null  int32
#  2   date                26281 non-null  object
#  3   hour_sin            26281 non-null  float64
#  4   hour_cos            26281 non-null  float64
#  5   weekday_sin         26281 non-null  float64
#  6   weekday_cos         26281 non-null  float64
#  7   is_dst              26281 non-null  bool
#  8   is_weekend          26281 non-null  bool
#  9   is_holiday          26281 non-null  bool
#  10  is_non_working_day  26281 non-null  bool
#  11  is_bouwvak          26281 non-null  bool
#  12  year                26281 non-null  int32
#  13  yearly_sin          26281 non-null  float64
#  14  yearly_cos          26281 non-null  float64
# dtypes: bool(5), datetime64[ns, UTC](1), float64(6), int32(2), object(1)
# memory usage: 1.9+ MB
# None
#               month      hour_sin      hour_cos   weekday_sin   weekday_cos  \
# count  26281.000000  2.628100e+04  2.628100e+04  26281.000000  26281.000000
# mean       6.517104 -1.879027e-17  3.805030e-05     -0.001575      0.001303
# std        3.446750  7.071068e-01  7.071337e-01      0.707161      0.707076
# min        1.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        4.000000 -7.071068e-01 -7.071068e-01     -0.781831     -0.900969
# 50%        7.000000  0.000000e+00  6.123234e-17      0.000000     -0.222521
# 75%       10.000000  7.071068e-01  7.071068e-01      0.781831      0.623490
# max       12.000000  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#                year    yearly_sin    yearly_cos
# count  26281.000000  26281.000000  26281.000000
# mean    2023.000038     -0.000004     -0.000647
# std        0.816520      0.707349      0.706891
# min     2022.000000     -0.999999     -0.999979
# 25%     2022.000000     -0.703677     -0.707487
# 50%     2023.000000     -0.004301      0.001075
# 75%     2024.000000      0.706727      0.702913
# max     2024.000000      0.999986      0.999991
#                     datetime  month        date      hour_sin      hour_cos  \
# 0  2022-01-01 00:00:00+00:00      1  2022-01-01  0.000000e+00  1.000000e+00
# 1  2022-01-01 01:00:00+00:00      1  2022-01-01  2.588190e-01  9.659258e-01
# 2  2022-01-01 02:00:00+00:00      1  2022-01-01  5.000000e-01  8.660254e-01
# 3  2022-01-01 03:00:00+00:00      1  2022-01-01  7.071068e-01  7.071068e-01
# 4  2022-01-01 04:00:00+00:00      1  2022-01-01  8.660254e-01  5.000000e-01
# 5  2022-01-01 05:00:00+00:00      1  2022-01-01  9.659258e-01  2.588190e-01
# 6  2022-01-01 06:00:00+00:00      1  2022-01-01  1.000000e+00  6.123234e-17
# 7  2022-01-01 07:00:00+00:00      1  2022-01-01  9.659258e-01 -2.588190e-01
# 8  2022-01-01 08:00:00+00:00      1  2022-01-01  8.660254e-01 -5.000000e-01
# 9  2022-01-01 09:00:00+00:00      1  2022-01-01  7.071068e-01 -7.071068e-01
# 10 2022-01-01 10:00:00+00:00      1  2022-01-01  5.000000e-01 -8.660254e-01
# 11 2022-01-01 11:00:00+00:00      1  2022-01-01  2.588190e-01 -9.659258e-01
# 12 2022-01-01 12:00:00+00:00      1  2022-01-01  1.224647e-16 -1.000000e+00
# 13 2022-01-01 13:00:00+00:00      1  2022-01-01 -2.588190e-01 -9.659258e-01
# 14 2022-01-01 14:00:00+00:00      1  2022-01-01 -5.000000e-01 -8.660254e-01
# 15 2022-01-01 15:00:00+00:00      1  2022-01-01 -7.071068e-01 -7.071068e-01
# 16 2022-01-01 16:00:00+00:00      1  2022-01-01 -8.660254e-01 -5.000000e-01
# 17 2022-01-01 17:00:00+00:00      1  2022-01-01 -9.659258e-01 -2.588190e-01
# 18 2022-01-01 18:00:00+00:00      1  2022-01-01 -1.000000e+00 -1.836970e-16
# 19 2022-01-01 19:00:00+00:00      1  2022-01-01 -9.659258e-01  2.588190e-01
# 20 2022-01-01 20:00:00+00:00      1  2022-01-01 -8.660254e-01  5.000000e-01
# 21 2022-01-01 21:00:00+00:00      1  2022-01-01 -7.071068e-01  7.071068e-01
# 22 2022-01-01 22:00:00+00:00      1  2022-01-01 -5.000000e-01  8.660254e-01
# 23 2022-01-01 23:00:00+00:00      1  2022-01-01 -2.588190e-01  9.659258e-01
#
#     weekday_sin  weekday_cos  is_dst  is_weekend  is_holiday  \
# 0     -0.974928    -0.222521   False        True        True
# 1     -0.974928    -0.222521   False        True        True
# 2     -0.974928    -0.222521   False        True        True
# 3     -0.974928    -0.222521   False        True        True
# 4     -0.974928    -0.222521   False        True        True
# 5     -0.974928    -0.222521   False        True        True
# 6     -0.974928    -0.222521   False        True        True
# 7     -0.974928    -0.222521   False        True        True
# 8     -0.974928    -0.222521   False        True        True
# 9     -0.974928    -0.222521   False        True        True
# 10    -0.974928    -0.222521   False        True        True
# 11    -0.974928    -0.222521   False        True        True
# 12    -0.974928    -0.222521   False        True        True
# 13    -0.974928    -0.222521   False        True        True
# 14    -0.974928    -0.222521   False        True        True
# 15    -0.974928    -0.222521   False        True        True
# 16    -0.974928    -0.222521   False        True        True
# 17    -0.974928    -0.222521   False        True        True
# 18    -0.974928    -0.222521   False        True        True
# 19    -0.974928    -0.222521   False        True        True
# 20    -0.974928    -0.222521   False        True        True
# 21    -0.974928    -0.222521   False        True        True
# 22    -0.974928    -0.222521   False        True        True
# 23    -0.974928    -0.222521   False        True        True
#
#     is_non_working_day  is_bouwvak  year  yearly_sin  yearly_cos
# 0                 True       False  2022    0.017202    0.999852
# 1                 True       False  2022    0.017202    0.999852
# 2                 True       False  2022    0.017202    0.999852
# 3                 True       False  2022    0.017202    0.999852
# 4                 True       False  2022    0.017202    0.999852
# 5                 True       False  2022    0.017202    0.999852
# 6                 True       False  2022    0.017202    0.999852
# 7                 True       False  2022    0.017202    0.999852
# 8                 True       False  2022    0.017202    0.999852
# 9                 True       False  2022    0.017202    0.999852
# 10                True       False  2022    0.017202    0.999852
# 11                True       False  2022    0.017202    0.999852
# 12                True       False  2022    0.017202    0.999852
# 13                True       False  2022    0.017202    0.999852
# 14                True       False  2022    0.017202    0.999852
# 15                True       False  2022    0.017202    0.999852
# 16                True       False  2022    0.017202    0.999852
# 17                True       False  2022    0.017202    0.999852
# 18                True       False  2022    0.017202    0.999852
# 19                True       False  2022    0.017202    0.999852
# 20                True       False  2022    0.017202    0.999852
# 21                True       False  2022    0.017202    0.999852
# 22                True       False  2022    0.017202    0.999852
# 23                True       False  2022    0.017202    0.999852
