# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
# Dynamic path setup
import sys
from pathlib import Path

# Find project root dynamically
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir

# Add utils to path
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set
 
df = build_training_set(
    train_start="2025-01-01 00:00:00",
    train_end="2025-03-14 23:00:00",
    run_date="2025-03-15 00:00:00"
)

print(df.tail())
df.to_csv("training_set1.csv", index=False)
# Out:
#         Price           target_datetime      Load  shortwave_radiation  \
# 1916  0.06842 2025-03-21 20:00:00+00:00  15700.25                  0.0
# 1917  0.04569 2025-03-21 21:00:00+00:00  14870.50                  0.0
# 1918  0.02923 2025-03-21 22:00:00+00:00  14056.25                  0.0
# 1919  0.02108 2025-03-21 23:00:00+00:00  13248.25                  0.0
# 1920  0.02693 2025-03-22 00:00:00+00:00  12561.25                  0.0
#
#       temperature_2m  direct_normal_irradiance  diffuse_radiation  Flow_NO  \
# 1916           13.05                       0.0                0.0    621.0
# 1917           13.00                       0.0                0.0    620.0
# 1918           12.60                       0.0                0.0    621.0
# 1919           12.00                       0.0                0.0    621.0
# 1920           10.05                       0.0                0.0    621.0
#
#       yearday_cos  Flow_GB  ...  is_dst  yearday_sin  wind_speed_10m  \
# 1916     0.193376 -1080.00  ...       0     0.981125       11.631956
# 1917     0.193376 -1076.50  ...       0     0.981125       12.979984
# 1918     0.193376 -1067.00  ...       0     0.981125       13.551501
# 1919     0.193376  -895.75  ...       0     0.981125       17.072504
# 1920     0.176471 -1071.00  ...       0     0.984306       12.181625
#
#       is_non_working_day  hour_cos  is_weekend  cloud_cover  weekday_sin  \
# 1916                   0  0.500000           0         32.0    -0.433884
# 1917                   0  0.707107           0         39.0    -0.433884
# 1918                   0  0.866025           0         52.0    -0.433884
# 1919                   0  0.965926           0         70.0    -0.433884
# 1920                   1  1.000000           1        100.0    -0.974928
#
#       hour_sin  weekday_cos
# 1916 -0.866025    -0.900969
# 1917 -0.707107    -0.900969
# 1918 -0.500000    -0.900969
# 1919 -0.258819    -0.900969
# 1920  0.000000    -0.222521
#
# [5 rows x 21 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
df['Timestamp'] = df['target_datetime']
# Feature engineering
df = df.dropna(subset=['target_datetime', 'Price'])

# Stel de periodes in
train_start = pd.Timestamp('2025-01-01', tz = 'UTC')
train_end = pd.Timestamp('2025-03-14 23:59:59', tz = 'UTC')
test_start = pd.Timestamp('2025-03-15', tz = 'UTC')
test_end = pd.Timestamp('2025-06-04 23:59:59', tz = 'UTC')

# Filter op basis van Timestamp
train = df[(df['Timestamp'] >= train_start) & (df['Timestamp'] <= train_end)]
test = df[(df['Timestamp'] >= test_start) & (df['Timestamp'] <= test_end)]

X_train = train[['weekday_sin', 'weekday_cos', 'hour_sin', 'hour_cos']]	
y_train = train['Price']
X_test = test[['weekday_sin', 'weekday_cos', 'hour_sin', 'hour_cos']]	
y_test = test['Price']

# Model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Evaluatie
from sklearn.metrics import mean_absolute_error
print("MAE:", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.03909749904648032
# MAE: 0.03909749904648032
# RMSE: 0.052045362881131936

# %%
from sklearn.ensemble import RandomForestRegressor

df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
df['Timestamp'] = df['target_datetime']
# Feature engineering
df = df.dropna(subset=['target_datetime', 'Price'])

# Stel de periodes in
train_start = pd.Timestamp('2025-01-01', tz = 'UTC')
train_end = pd.Timestamp('2025-03-14 23:59:59', tz = 'UTC')
test_start = pd.Timestamp('2025-03-15', tz = 'UTC')
test_end = pd.Timestamp('2025-06-04 23:59:59', tz = 'UTC')

# Filter op basis van Timestamp
train = df[(df['Timestamp'] >= train_start) & (df['Timestamp'] <= train_end)]
test = df[(df['Timestamp'] >= test_start) & (df['Timestamp'] <= test_end)]

# Features voor het model
features = [
    'Flow_NO',  'hour_sin', 
    'Load','shortwave_radiation', 'temperature_2m', 
    'Flow_GB', 'weekday_sin'
] # excluded: 'month', 'yearday_sin', 'weekday_cos', diffuse_radiation', 'yearday_cos', 'hour_cos','is_dst','is_non_working_day', 'is_weekend','cloud_cover','direct_normal_irradiance',


X_train = train[features]
y_train = train['Price']
X_test = test[features]
y_test = test['Price']

# Model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Evaluatie
from sklearn.metrics import mean_absolute_error
print("MAE:", mean_absolute_error(y_test, y_pred))

from sklearn.metrics import mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.026245930769230773
# MAE: 0.026245930769230773
# RMSE: 0.03816810915619053

# %%
import matplotlib.pyplot as plt

importances = model.feature_importances_
feature_names = X_train.columns

plt.figure(figsize=(8, 4))
plt.barh(feature_names, importances)
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importances")
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(y_test.values, label='Actual', marker='o')
plt.plot(y_pred, label='Predicted', marker='x')
plt.legend()
plt.title("Actual vs Predicted Prices")
plt.xlabel("Sample")
plt.ylabel("Price")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

# Define feature columns and target
FEATURES = ['weekday_cos', 'weekday_sin', 'hour_cos', 'hour_sin', 'yearday_cos', 'yearday_sin']
TRAIN_FEATURES = FEATURES
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing Random Forest Model - RMSE per forecast day")
print("=" * 60)

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Train model
        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)

        # Zorg dat alle features aanwezig zijn in test_data
        for col in TRAIN_FEATURES:
            if col not in test_data.columns:
                test_data[col] = np.nan

        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]

        # Alleen voorspellen als er nog testdata over is
        if len(X_test) > 0:
            y_pred = model.predict(X_test)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(X_test),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(X_test)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - Random Forest Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 🔍 Testing Random Forest Model - RMSE per forecast day
# ============================================================
# Day 1: ✅ 144 test rows, Run: 03-15
# Day 2: ✅ 144 test rows, Run: 03-16
# Day 3: ✅ 144 test rows, Run: 03-17
# Day 4: ✅ 144 test rows, Run: 03-18
# Day 5: ✅ 144 test rows, Run: 03-19
# Day 6: ✅ 144 test rows, Run: 03-20
# Day 7: ✅ 144 test rows, Run: 03-21
# Day 8: ✅ 144 test rows, Run: 03-22
# Day 9: ✅ 144 test rows, Run: 03-23
# Day 10: ✅ 144 test rows, Run: 03-24
# Day 11: ✅ 144 test rows, Run: 03-25
# Day 12: ✅ 144 test rows, Run: 03-26
# Day 13: ✅ 144 test rows, Run: 03-27
# Day 14: ✅ 144 test rows, Run: 03-28
# Day 15: ✅ 144 test rows, Run: 03-29
# Day 16: ✅ 144 test rows, Run: 03-30
# Day 17: ✅ 144 test rows, Run: 03-31
# Day 18: ✅ 144 test rows, Run: 04-01
# Day 19: ✅ 144 test rows, Run: 04-02
# Day 20: ✅ 144 test rows, Run: 04-03
# Day 21: ✅ 144 test rows, Run: 04-04
# Day 22: ✅ 144 test rows, Run: 04-05
# Day 23: ✅ 144 test rows, Run: 04-06
# Day 24: ✅ 144 test rows, Run: 04-07
# Day 25: ✅ 144 test rows, Run: 04-08
# Day 26: ✅ 144 test rows, Run: 04-09
# Day 27: ✅ 144 test rows, Run: 04-10
# Day 28: ✅ 144 test rows, Run: 04-11
# Day 29: ✅ 144 test rows, Run: 04-12
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - Random Forest Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.05
#          2 2025-03-16                144  0.05
#          3 2025-03-17                144  0.03
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.04
#          9 2025-03-23                144  0.06
#         10 2025-03-24                144  0.05
#         11 2025-03-25                144  0.05
#         12 2025-03-26                144  0.05
#         13 2025-03-27                144  0.06
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.04
#         16 2025-03-30                144  0.04
#         17 2025-03-31                144  0.05
#         18 2025-04-01                144  0.03
#         19 2025-04-02                144  0.03
#         20 2025-04-03                144  0.03
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.02
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.02
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.02
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.03
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.04
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.04
# 75%       0.05
# max       0.06
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0365
# Stddev RMSE: 0.0115

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

# Define feature columns and target
FEATURES = ['Load', 'shortwave_radiation', 'temperature_2m', 
            'direct_normal_irradiance', 'diffuse_radiation', 
            'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 
            'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 
            'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 
            'hour_sin', 'weekday_cos']
TRAIN_FEATURES = FEATURES
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing Random Forest Model - RMSE per forecast day")
print("=" * 60)

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Train model
        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)

        # Zorg dat alle features aanwezig zijn in test_data
        for col in TRAIN_FEATURES:
            if col not in test_data.columns:
                test_data[col] = np.nan

        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]

        # Alleen voorspellen als er nog testdata over is
        if len(X_test) > 0:
            y_pred = model.predict(X_test)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(X_test),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(X_test)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - Random Forest Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-31 11:18:36,326 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-31 11:18:36,326 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:18:36,334 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-31 11:18:36,337 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 11:18:36,338 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:18:36,338 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 11:18:36,346 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:18:36,437 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 11:18:36,444 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 11:18:36,467 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:18:36,467 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 🔍 Testing Random Forest Model - RMSE per forecast day
# ============================================================
# 2025-05-31 11:18:36,521 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:18:36,521 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:18:36,524 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:18:36,526 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:18:36,527 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:18:36,624 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 11:18:36,625 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:18:36,698 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:18:36,702 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:18:36,789 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:18:36,793 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:18:36,795 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:18:36,804 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:18:36,850 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:18:36,851 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:18:36,855 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:18:36,857 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 11:18:36,857 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 11:18:36,857 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:18:36,857 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 11:18:36,857 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 11:18:36,867 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 11:18:36,925 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:18:36,927 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 11:18:38,801 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-31 11:18:38,803 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:18:38,805 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-31 11:18:38,805 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-31 11:18:38,805 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:18:38,812 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 11:18:38,814 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:18:38,863 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 11:18:38,863 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 11:18:38,875 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:18:38,884 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:18:38,906 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:18:38,910 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:18:38,910 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:18:38,911 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:18:38,914 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:18:38,976 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-31 11:18:38,977 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:18:39,058 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:18:39,058 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:18:39,181 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:18:39,183 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:18:39,188 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:18:39,191 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:18:39,238 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:18:39,240 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:18:39,244 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:18
- build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:19:43,546 - build_training_set - INFO - 🔒 Connection closed
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - Random Forest Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.04
#          2 2025-03-16                144  0.04
#          3 2025-03-17                144  0.04
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.03
#          9 2025-03-23                144  0.04
#         10 2025-03-24                144  0.04
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.04
#         13 2025-03-27                144  0.05
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.04
#         16 2025-03-30                144  0.04
#         17 2025-03-31                144  0.04
#         18 2025-04-01                144  0.04
#         19 2025-04-02                144  0.03
#         20 2025-04-03                144  0.02
#         21 2025-04-04                144  0.02
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.03
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.03
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.02
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.03
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.04
# 75%       0.04
# max       0.05
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0344
# Stddev RMSE: 0.0084

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Example: Use your initial training set to select features
df = build_training_set(
    train_start="2025-01-01 00:00:00",
    train_end="2025-03-14 23:00:00",
    run_date="2025-03-15 00:00:00"
)
df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
df = df.sort_values('target_datetime').set_index('target_datetime')

# Define all candidate features
ALL_FEATURES = [
    'Load', 'shortwave_radiation', 'temperature_2m', 
    'direct_normal_irradiance', 'diffuse_radiation', 
    'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 
    'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 
    'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 
    'hour_sin', 'weekday_cos'
]
target = 'Price'

# Drop missing values
df = df.dropna(subset=ALL_FEATURES + [target])

# Train a Random Forest to get feature importances
X = df[ALL_FEATURES]
y = df[target]
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y)

importances = model.feature_importances_
feat_imp_df = pd.DataFrame({
    'Feature': ALL_FEATURES,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Print top N features
N = 10
print(f"Top {N} features by importance:")
print(feat_imp_df.head(N))

# If you want to use the top N features for your model:
SELECTED_FEATURES = feat_imp_df['Feature'].head(N).tolist()
print("Selected features for the model:", SELECTED_FEATURES)
# Out:
# 2025-05-30 16:18:41,261 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-30 16:18:41,261 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:18:41,262 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-30 16:18:41,264 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:18:41,265 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:18:41,270 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:18:41,271 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:18:41,329 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:18:41,330 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:18:41,352 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:18:41,355 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:18:41,372 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:18:41,375 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:18:41,376 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:18:41,377 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:18:41,378 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:18:41,479 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:18:41,480 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:18:41,557 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:18:41,559 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:18:41,612 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:18:41,614 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:18:41,614 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:18:41,621 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:18:41,648 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:18:41,649 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:18:41,652 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:18:41,655 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:18:41,657 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:18:41,657 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:18:41,658 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:18:41,660 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:18:41,663 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:18:41,703 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:18:41,706 - build_training_set - INFO - 🔒 Connection closed
# Top 10 features by importance:
#                 Feature  Importance
# 0                  Load    0.354329
# 11       wind_speed_10m    0.176429
# 5               Flow_NO    0.134838
# 2        temperature_2m    0.095082
# 6           yearday_cos    0.043127
# 10          yearday_sin    0.041789
# 1   shortwave_radiation    0.034446
# 7               Flow_GB    0.026510
# 4     diffuse_radiation    0.020868
# 17             hour_sin    0.017968
# Selected features for the model: ['Load', 'wind_speed_10m', 'Flow_NO', 'temperature_2m', 'yearday_cos', 'yearday_sin', 'shortwave_radiation', 'Flow_GB', 'diffuse_radiation', 'hour_sin']

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

FEATURES = ['Load', 'wind_speed_10m', 'Flow_NO', 'temperature_2m', 'yearday_cos', 
            'yearday_sin', 'shortwave_radiation', 'Flow_GB', 'diffuse_radiation', 'hour_sin', 'hour_cos']
TRAIN_FEATURES = FEATURES
target = 'Price'

base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []
all_preds = []

print("🔍 Testing Random Forest Model - RMSE per forecast day")
print("=" * 60)

for i in range(63):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]

        # Drop any missing data in training and test
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])
        test_data = test_data.dropna(subset=TRAIN_FEATURES + [target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]
        test_index = X_test.index

        if len(X_test) > 0:
            model = RandomForestRegressor(n_estimators=100, random_state=42)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
            # Save predictions with run_date, target_datetime, predicted and actual price
            preds_df = pd.DataFrame({
                'run_date': run_date.strftime('%Y-%m-%d'),
                'target_datetime': test_index,
                'predicted_Price': y_pred,
                'actual_Price': y_test.values
            })
            all_preds.append(preds_df)
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(X_test),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(X_test)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Save all predictions to CSV
if all_preds:
    all_preds_df = pd.concat(all_preds, ignore_index=True)
    all_preds_df.to_csv("random_forest_predictions_with_actuals.csv", index=False)
    print("Predictions with actuals saved to random_forest_predictions_with_actuals.csv")
else:
    print("No predictions to save.")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - Random Forest Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 🔍 Testing Random Forest Model - RMSE per forecast day
# ============================================================
# Day 1: ✅ 144 test rows, Run: 03-15
# Day 2: ✅ 144 test rows, Run: 03-16
# Day 3: ✅ 144 test rows, Run: 03-17
# Day 4: ✅ 144 test rows, Run: 03-18
# Day 5: ✅ 144 test rows, Run: 03-19
# Day 6: ✅ 144 test rows, Run: 03-20
# Day 7: ✅ 144 test rows, Run: 03-21
# Day 8: ✅ 144 test rows, Run: 03-22
# Day 9: ✅ 144 test rows, Run: 03-23
# Day 10: ✅ 144 test rows, Run: 03-24
# Day 11: ✅ 144 test rows, Run: 03-25
# Day 12: ✅ 144 test rows, Run: 03-26
# Day 13: ✅ 144 test rows, Run: 03-27
# Day 14: ✅ 144 test rows, Run: 03-28
# Day 15: ✅ 144 test rows, Run: 03-29
# Day 16: ✅ 144 test rows, Run: 03-30
# Day 17: ✅ 144 test rows, Run: 03-31
# Day 18: ✅ 144 test rows, Run: 04-01
# Day 19: ✅ 144 test rows, Run: 04-02
# Day 20: ✅ 144 test rows, Run: 04-03
# Day 21: ✅ 144 test rows, Run: 04-04
# Day 22: ✅ 144 test rows, Run: 04-05
# Day 23: ✅ 144 test rows, Run: 04-06
# Day 24: ✅ 144 test rows, Run: 04-07
# Day 25: ✅ 144 test rows, Run: 04-08
# Day 26: ✅ 144 test rows, Run: 04-09
# Day 27: ✅ 144 test rows, Run: 04-10
# Day 28: ✅ 144 test rows, Run: 04-11
# Day 29: ✅ 144 test rows, Run: 04-12
# Day 30: ✅ 144 test rows, Run: 04-13
# Day 31: ✅ 144 test rows, Run: 04-14
# Day 32: ✅ 144 test rows, Run: 04-15
# Day 33: ✅ 144 test rows, Run: 04-16
# Day 34: ✅ 144 test rows, Run: 04-17
# Day 35: ✅ 144 test rows, Run: 04-18
# Day 36: ✅ 144 test rows, Run: 04-19
# Day 37: ✅ 144 test rows, Run: 04-20
# Day 38: ✅ 144 test rows, Run: 04-21
# Day 39: ✅ 144 test rows, Run: 04-22
# Day 40: ✅ 144 test rows, Run: 04-23
# Day 41: ✅ 144 test rows, Run: 04-24
# Day 42: ✅ 144 test rows, Run: 04-25
# Day 43: ✅ 144 test rows, Run: 04-26
# Day 44: ✅ 144 test rows, Run: 04-27
# Day 45: ✅ 144 test rows, Run: 04-28
# Day 46: ✅ 144 test rows, Run: 04-29
# Day 47: ✅ 144 test rows, Run: 04-30
# Day 48: ✅ 144 test rows, Run: 05-01
# Day 49: ✅ 144 test rows, Run: 05-02
# Day 50: ✅ 144 test rows, Run: 05-03
# Day 51: ✅ 144 test rows, Run: 05-04
# Day 52: ✅ 144 test rows, Run: 05-05
# Day 53: ✅ 144 test rows, Run: 05-06
# Day 54: ✅ 144 test rows, Run: 05-07
# Day 55: ✅ 144 test rows, Run: 05-08
# Day 56: ✅ 144 test rows, Run: 05-09
# Day 57: ✅ 144 test rows, Run: 05-10
# Day 58: ✅ 144 test rows, Run: 05-11
# Day 59: ✅ 144 test rows, Run: 05-12
# Day 60: ✅ 144 test rows, Run: 05-13
# Day 61: ✅ 144 test rows, Run: 05-14
# Day 62: ✅ 144 test rows, Run: 05-15
# Day 63: ✅ 144 test rows, Run: 05-16
# Predictions with actuals saved to random_forest_predictions_with_actuals.csv
#
# 📊 OVERALL RMSE - Random Forest Model
# ================================================================================
# Successful runs: 63/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.04
#          2 2025-03-16                144  0.04
#          3 2025-03-17                144  0.04
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.03
#          9 2025-03-23                144  0.04
#         10 2025-03-24                144  0.04
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.04
#         13 2025-03-27                144  0.05
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.04
#         16 2025-03-30                144  0.04
#         17 2025-03-31                144  0.04
#         18 2025-04-01                144  0.04
#         19 2025-04-02                144  0.03
#         20 2025-04-03                144  0.02
#         21 2025-04-04                144  0.02
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.03
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.03
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.02
#         31 2025-04-14                144  0.03
#         32 2025-04-15                144  0.02
#         33 2025-04-16                144  0.03
#         34 2025-04-17                144  0.03
#         35 2025-04-18                144  0.03
#         36 2025-04-19                144  0.03
#         37 2025-04-20                144  0.02
#         38 2025-04-21                144  0.03
#         39 2025-04-22                144  0.03
#         40 2025-04-23                144  0.03
#         41 2025-04-24                144  0.03
#         42 2025-04-25                144  0.05
#         43 2025-04-26                144  0.05
#         44 2025-04-27                144  0.04
#         45 2025-04-28                144  0.04
#         46 2025-04-29                144  0.04
#         47 2025-04-30                144  0.04
#         48 2025-05-01                144  0.03
#         49 2025-05-02                144  0.03
#         50 2025-05-03                144  0.03
#         51 2025-05-04                144  0.03
#         52 2025-05-05                144  0.06
#         53 2025-05-06                144  0.05
#         54 2025-05-07                144  0.04
#         55 2025-05-08                144  0.04
#         56 2025-05-09                144  0.05
#         57 2025-05-10                144  0.04
#         58 2025-05-11                144  0.03
#         59 2025-05-12                144  0.03
#         60 2025-05-13                144  0.02
#         61 2025-05-14                144  0.02
#         62 2025-05-15                144  0.02
#         63 2025-05-16                144  0.04
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    63.00
# mean      0.03
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.03
# 75%       0.04
# max       0.06
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0343
# Stddev RMSE: 0.0088

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

FEATURES = ['Load', 'wind_speed_10m', 'Flow_NO', 'temperature_2m', 'yearday_sin', 'yearday_cos', 'shortwave_radiation', 'Flow_GB', 'diffuse_radiation', 'hour_sin']
TRAIN_FEATURES = FEATURES
target = 'Price'

base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

all_preds = []

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )
        if df is None or df.empty:
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')
        run_date_utc = run_date.tz_localize("UTC")

        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])
        test_data = test_data.dropna(subset=TRAIN_FEATURES + [target])
        if test_data.empty or train_data.empty:
            continue

        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]
        test_index = X_test.index

        if len(X_test) > 0:
            model = RandomForestRegressor(n_estimators=100, random_state=42)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            # Save predictions with run_date, target_datetime, predicted and actual price
            preds_df = pd.DataFrame({
                'run_date': run_date.strftime('%Y-%m-%d'),
                'target_datetime': test_index,
                'predicted_Price': y_pred,
                'actual_Price': y_test.values
            })
            all_preds.append(preds_df)
    except Exception as e:
        print(f"Error on day {i+1}: {e}")

# Combine and save to CSV
if all_preds:
    all_preds_df = pd.concat(all_preds, ignore_index=True)
    all_preds_df.to_csv("random_forest_predictions_with_actuals.csv", index=False)
    print("Predictions with actuals saved to random_forest_predictions_with_actuals.csv")
else:
    print("No predictions to save.")

    # Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - Random Forest Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-31 11:16:07,088 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-31 11:16:07,117 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:16:07,117 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-31 11:16:07,117 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 11:16:07,134 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:16:07,326 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 11:16:07,326 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:07,484 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 11:16:07,484 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 11:16:07,506 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:16:07,508 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:07,541 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:16:07,549 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:16:07,549 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:16:07,555 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:16:07,555 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:16:07,723 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 11:16:07,723 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:16:07,841 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:16:07,842 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:16:07,930 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:16:07,948 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:16:07,949 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:16:07,959 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:16:08,007 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:16:08,007 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:16:08,023 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:16:08,032 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 11:16:08,037 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 11:16:08,038 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:08,041 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 11:16:08,042 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 11:16:08,042 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 11:16:08,158 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:16:08,158 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:16:09,965 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 11:16:09,982 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:10,065 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 11:16:10,065 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 11:16:10,102 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:16:10,108 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:10,140 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:16:10,143 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:16:10,143 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:16:10,143 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:16:10,143 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:16:10,250 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 11:16:10,251 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:16:10,300 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:16:10,314 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:16:10,424 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:16:10,433 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:16:10,433 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:16:10,436 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:16:10,469 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:16:10,481 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:16:10,483 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:16:10,483 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 11:16:10,483 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 11:16:10,483 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:16:10,483 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-31 11:16:10,483 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 11:16:10,483 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 11:16:10,579 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:16:10,581 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 11:16:12,069 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-31 11:16:12,072 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:16:12,072 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-31 11:16:12,072 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-31 11:16:12,072 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:16
- build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:17:10,652 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:17:10,687 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:17:10,703 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:17:10,703 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:17:10,703 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:17:10,718 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:17:10,836 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 11:17:10,836 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:17:10,969 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:17:10,969 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:17:11,102 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:17:11,102 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:17:11,110 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:17:11,123 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:17:11,185 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:17:11,185 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:17:11,185 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:17:11,194 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 11:17:11,194 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 11:17:11,202 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:17:11,202 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-31 11:17:11,202 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 11:17:11,210 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 11:17:11,286 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:17:11,286 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 11:17:13,994 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-05-31 11:17:13,994 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 11:17:14,003 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-05-31 11:17:14,004 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-31 11:17:14,006 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 11:17:14,006 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 11:17:14,006 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:17:14,102 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 11:17:14,102 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 11:17:14,127 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 11:17:14,136 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:17:14,169 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 11:17:14,194 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 11:17:14,198 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 11:17:14,205 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 11:17:14,208 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 11:17:14,335 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 11:17:14,335 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 11:17:14,453 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 11:17:14,453 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 11:17:14,569 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 11:17:14,576 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 11:17:14,576 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 11:17:14,586 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 11:17:14,636 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 11:17:14,636 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 11:17:14,652 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 11:17:14,657 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 11:17:14,657 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 11:17:14,657 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 11:17:14,668 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-31 11:17:14,668 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 11:17:14,673 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 11:17:14,753 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 11:17:14,761 - build_training_set - INFO - 🔒 Connection closed
# Predictions with actuals saved to random_forest_predictions_with_actuals.csv
#
# 📊 OVERALL RMSE - Random Forest Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.05
#          2 2025-03-16                144  0.05
#          3 2025-03-17                144  0.03
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.04
#          9 2025-03-23                144  0.06
#         10 2025-03-24                144  0.05
#         11 2025-03-25                144  0.05
#         12 2025-03-26                144  0.05
#         13 2025-03-27                144  0.06
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.04
#         16 2025-03-30                144  0.04
#         17 2025-03-31                144  0.05
#         18 2025-04-01                144  0.03
#         19 2025-04-02                144  0.03
#         20 2025-04-03                144  0.03
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.02
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.02
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.02
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.03
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.04
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.04
# 75%       0.05
# max       0.06
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0366
# Stddev RMSE: 0.0114
