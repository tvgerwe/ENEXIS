# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing SARIMA Model - RMSE per forecast day")
print("=" * 60)

# SARIMA parameters (example: adjust as needed)
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 24)  # 24 for hourly data with daily seasonality

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df['target_datetime'] <= run_date_utc]
        test_data = df[df['target_datetime'] > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=['target_datetime', target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Prepare data for SARIMA
        # Zorg dat index datetime64[ns] en zonder tz is
        train_data['target_datetime'] = pd.to_datetime(train_data['target_datetime']).dt.tz_localize(None)
        test_data['target_datetime'] = pd.to_datetime(test_data['target_datetime']).dt.tz_localize(None)
        y_train = train_data.set_index('target_datetime')[target].astype(float)
        y_test = test_data.set_index('target_datetime')[target].astype(float)

        # Fit SARIMA model
        model = SARIMAX(y_train, order=order, seasonal_order=seasonal_order, enforce_stationarity=False, enforce_invertibility=False)
        model_fit = model.fit(disp=False)

        # Forecast for the test period
        n_test = len(y_test)
        forecast = model_fit.forecast(steps=n_test)
        y_pred = forecast.values

        # Sla de eerste 24 uur over
        if len(y_pred) > 24:
            y_pred = y_pred[24:]
            y_test = y_test[24:]
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan
            rmse_results.append({
                'iteration': i + 1,
                'run_date': run_date.strftime('%Y-%m-%d'),
                'valid_predictions': 0,
                'rmse': rmse
            })
            continue

        if len(y_pred) > 0:
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(y_pred),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(y_pred)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - SARIMA Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-31 20:47:23,631 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-31 20:47:23,631 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:47:23,632 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-31 20:47:23,632 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 20:47:23,632 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:47:23,633 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:47:23,634 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:23,644 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:47:23,644 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:47:23,649 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:47:23,649 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:23,653 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:47:23,653 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:47:23,653 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:47:23,654 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:47:23,654 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:47:23,686 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:47:23,687 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:47:23,709 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:47:23,710 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:47:23,733 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:47:23,734 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:47:23,734 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:47:23,736 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:47:23,748 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:47:23,748 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:47:23,749 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:47:23,751 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:47:23,751 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:47:23,752 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:23,752 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-31 20:47:23,752 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:47:23,753 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:47:23,760 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:47:23,761 - build_training_set - INFO - 🔒 Connection closed
# 🔍 Testing SARIMA Model - RMSE per forecast day
# ============================================================
# 2025-05-31 20:47:34,636 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-31 20:47:34,637 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:47:34,638 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-31 20:47:34,639 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-31 20:47:34,640 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:47:34,642 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:47:34,643 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:34,676 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:47:34,676 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:47:34,687 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:47:34,690 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:34,698 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:47:34,700 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:47:34,701 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:47:34,701 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:47:34,702 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:47:34,750 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:47:34,751 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:47:34,787 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:47:34,788 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:47:34,818 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:47:34,819 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:47:34,819 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:47:34,822 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-31 20:47:34,844 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:47:34,845 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:47:34,847 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:47:34,848 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:47:34,850 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:47:34,851 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:34,852 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-31 20:47:34,852 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:47:34,854 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:47:34,872 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:47:34,873 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:47:44,306 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-31 20:47:44,307 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:47:44,308 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-31 20:47:44,309 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-31 20:47:44,309 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:47:44,314 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:47:44,314 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:44,335 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:47:44,337 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:47:44,344 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:47:44,346 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:44,354 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:47:44,354 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:47:44,355 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:47:44,355 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:47:44,356 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:47:44,395 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:47:44,396 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:47:44,422 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:47:44,423 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:47:44,449 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:47:44,450 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:47:44,452 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:47:44,456 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:47:44,484 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:47:44,485 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:47:44,488 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:47:44,492 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:47:44,493 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:47:44,495 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:44,497 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-31 20:47:44,498 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:47:44,500 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-05-31 20:47:44,517 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:47:44,520 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:47:57,117 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-05-31 20:47:57,118 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:47:57,118 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-05-31 20:47:57,121 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-31 20:47:57,122 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:47:57,124 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:47:57,124 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:57,142 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:47:57,143 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:47:57,152 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:47:57,154 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:57,160 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:47:57,162 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:47:57,163 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:47:57,163 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:47:57,164 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:47:57,201 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:47:57,202 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:47:57,245 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:47:57,246 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:47:57,275 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:47:57,276 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:47:57,277 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:47:57,280 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:47:57,301 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:47:57,302 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:47:57,304 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:47:57,306 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:47:57,307 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:47:57,307 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:47:57,308 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-31 20:47:57,309 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:47:57,312 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-05-31 20:47:57,323 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:47:57,325 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:03,893 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:03,893 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:03,894 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:03,895 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-31 20:48:03,897 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:03,901 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:03,902 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:03,920 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:03,921 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:03,928 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:03,929 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:03,933 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:03,934 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:03,935 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:03,937 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:03,939 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:03,986 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:03,986 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:04,024 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:04,025 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:04,055 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:04,057 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:04,058 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:04,061 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:04,079 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-05-31 20:48:04,097 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:04,099 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:48:04,101 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:04,103 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:04,104 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:04,105 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-31 20:48:04,107 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:48:04,110 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:48:04,125 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:04,126 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:13,150 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:13,151 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:13,151 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:13,152 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-31 20:48:13,153 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:13,155 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:13,156 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:13,174 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:13,176 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:13,180 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:13,193 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:13,199 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:13,200 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:13,200 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:13,201 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:13,202 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:13,248 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:13,249 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:13,285 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:13,286 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:13,310 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:13,312 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:13,312 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:13,315 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:13,336 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:48:13,336 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:13,339 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:48:13,343 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:13,344 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:13,346 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:13,346 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-31 20:48:13,347 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:48:13,350 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-05-31 20:48:13,367 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:13,369 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:21,721 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:21,721 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:21,722 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:21,723 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-31 20:48:21,725 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:21,727 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:21,727 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:21,752 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:21,752 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:21,756 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:21,758 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:21,765 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:21,766 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:21,766 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:21,767 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:21,767 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:21,804 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:21,808 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:21,833 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:21,834 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:21,855 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:21,859 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:21,860 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:21,863 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:21,880 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:48:21,881 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:21,883 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:48:21,886 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:21,887 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:21,888 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:21,888 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-31 20:48:21,889 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:48:21,892 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:48:21,912 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:21,913 - build_training_set - INFO - 🔒 Connection closed
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-05-31 20:48:30,398 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:30,399 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:30,400 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:30,401 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-31 20:48:30,403 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:30,405 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:30,406 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:30,424 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:30,425 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:30,430 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:30,432 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:30,441 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:30,442 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:30,442 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:30,443 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:30,444 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:30,485 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:30,485 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:30,533 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:30,534 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:30,561 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:30,562 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:30,563 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:30,565 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:30,588 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:48:30,589 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:30,591 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:48:30,594 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:30,595 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:30,595 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:30,596 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-31 20:48:30,597 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-05-31 20:48:30,598 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:48:30,613 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:30,614 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:40,221 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:40,222 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:40,223 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:40,224 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-31 20:48:40,226 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:40,228 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:40,229 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:40,257 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:40,258 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:40,265 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:40,266 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:40,274 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:40,275 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:40,275 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:40,276 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:40,276 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:40,310 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:40,311 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:40,347 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:40,347 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:40,375 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:40,376 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:40,377 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:40,380 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:40,412 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:48:40,420 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:40,422 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-05-31 20:48:40,423 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:40,425 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:40,426 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:40,427 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-31 20:48:40,428 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:48:40,430 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-31 20:48:40,449 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:40,450 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:49,083 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:49,084 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:49,084 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:49,086 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-31 20:48:49,088 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:49,092 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:49,093 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:49,115 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:49,116 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:49,122 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-31 20:48:49,124 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:49,128 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-31 20:48:49,128 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-31 20:48:49,129 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-31 20:48:49,129 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-31 20:48:49,130 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-31 20:48:49,180 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-31 20:48:49,181 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-31 20:48:49,208 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-31 20:48:49,211 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-31 20:48:49,240 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-31 20:48:49,242 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-31 20:48:49,242 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-31 20:48:49,245 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-31 20:48:49,262 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-31 20:48:49,263 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-31 20:48:49,264 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-31 20:48:49,267 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-31 20:48:49,269 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-31 20:48:49,269 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:49,270 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-31 20:48:49,271 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-31 20:48:49,276 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-05-31 20:48:49,295 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-31 20:48:49,299 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-31 20:48:59,470 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-05-31 20:48:59,470 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-31 20:48:59,471 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-05-31 20:48:59,473 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-05-31 20:48:59,474 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-31 20:48:59,476 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-31 20:48:59,478 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-31 20:48:59,499 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-31 20:48:59,500 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-31 20:48:59,509 - build_training_set - INFO - 📊 Forecast rows available: 169
# ...
# 2025-06-01 03:01:23,909 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 03:33:06,977 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-06-01 03:33:06,977 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 03:33:06,978 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-06-01 03:33:06,979 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-06-01 03:33:06,980 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 03:33:06,981 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 03:33:06,982 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:07,016 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 03:33:07,057 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 03:33:07,073 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 03:33:07,075 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:07,080 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 03:33:07,080 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 03:33:07,081 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 03:33:07,081 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 03:33:07,082 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 03:33:07,120 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 03:33:07,121 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 03:33:07,153 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 03:33:07,154 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-06-01 03:33:07,207 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 03:33:07,208 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 03:33:07,208 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 03:33:07,210 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 03:33:07,222 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 03:33:07,222 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 03:33:07,223 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 03:33:07,225 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 03:33:07,226 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 03:33:07,226 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:07,226 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-06-01 03:33:07,227 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 03:33:07,229 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 03:33:07,238 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 03:33:07,239 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 03:33:18,939 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-06-01 03:33:18,940 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 03:33:18,940 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-06-01 03:33:18,941 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-06-01 03:33:18,943 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 03:33:18,945 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 03:33:18,946 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:18,966 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 03:33:18,967 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 03:33:18,975 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 03:33:18,977 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:18,985 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 03:33:18,987 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 03:33:18,987 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 03:33:18,989 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 03:33:18,990 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 03:33:19,039 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 03:33:19,040 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 03:33:19,076 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 03:33:19,076 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 03:33:19,122 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 03:33:19,123 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 03:33:19,123 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 03:33:19,127 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-06-01 03:33:19,150 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 03:33:19,151 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 03:33:19,152 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 03:33:19,154 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 03:33:19,155 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 03:33:19,155 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 03:33:19,155 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-06-01 03:33:19,156 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 03:33:19,157 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 03:33:19,167 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 03:33:19,168 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 04:07:11,961 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-06-01 04:07:11,961 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 04:07:11,962 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-06-01 04:07:11,963 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-06-01 04:07:11,965 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 04:07:11,967 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 04:07:11,968 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:07:11,990 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 04:07:11,991 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 04:07:11,997 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 04:07:11,998 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:07:12,003 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 04:07:12,005 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 04:07:12,005 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 04:07:12,006 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 04:07:12,007 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 04:07:12,043 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 04:07:12,044 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 04:07:12,068 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 04:07:12,069 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 04:07:12,095 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 04:07:12,097 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 04:07:12,097 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 04:07:12,102 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 04:07:12,124 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 04:07:12,127 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 04:07:12,129 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 04:07:12,133 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 04:07:12,134 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 04:07:12,135 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:07:12,136 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-06-01 04:07:12,137 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 04:07:12,139 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 04:07:12,150 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 04:07:12,152 - build_training_set - INFO - 🔒 Connection closed
# Day 29: ✅ 144 test rows, Run: 04-12
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - SARIMA Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.05
#          2 2025-03-16                144  0.04
#          3 2025-03-17                144  0.06
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.05
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.12
#          9 2025-03-23                144  0.02
#         10 2025-03-24                144  0.05
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.05
#         13 2025-03-27                144  0.05
#         14 2025-03-28                144  0.04
#         15 2025-03-29                144  0.06
#         16 2025-03-30                144  0.11
#         17 2025-03-31                144  0.04
#         18 2025-04-01                144  0.05
#         19 2025-04-02                144  0.04
#         20 2025-04-03                144  0.04
#         21 2025-04-04                144  0.05
#         22 2025-04-05                144  0.03
#         23 2025-04-06                144  0.05
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.03
#         26 2025-04-09                144  0.03
#         27 2025-04-10                144  0.03
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.04
#         30 2025-04-13                144  0.04
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.05
# std       0.02
# min       0.02
# 25%       0.04
# 50%       0.04
# 75%       0.05
# max       0.12
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0455
# Stddev RMSE: 0.0209

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

FEATURES = [
    'Load', 'shortwave_radiation', 'temperature_2m', 
    'direct_normal_irradiance', 'diffuse_radiation', 
    'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 
    'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 
    'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 
    'hour_sin', 'weekday_cos'
]
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing SARIMAX Model - RMSE per forecast day")
print("=" * 60)

# SARIMAX parameters (example: adjust as needed)
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 24)  # 24 for hourly data with daily seasonality

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df['target_datetime'] <= run_date_utc]
        test_data = df[df['target_datetime'] > run_date_utc]

        # Drop any missing data in training and test
        train_data = train_data.dropna(subset=['target_datetime', target] + FEATURES)
        test_data = test_data.dropna(subset=['target_datetime', target] + FEATURES)

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Prepare data for SARIMAX
        train_data['target_datetime'] = pd.to_datetime(train_data['target_datetime']).dt.tz_localize(None)
        test_data['target_datetime'] = pd.to_datetime(test_data['target_datetime']).dt.tz_localize(None)
        y_train = train_data.set_index('target_datetime')[target].astype(float)
        y_test = test_data.set_index('target_datetime')[target].astype(float)
        exog_train = train_data.set_index('target_datetime')[FEATURES].astype(float)
        exog_test = test_data.set_index('target_datetime')[FEATURES].astype(float)

        # Fit SARIMAX model with exogenous variables
        model = SARIMAX(
            y_train,
            exog=exog_train,
            order=order,
            seasonal_order=seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        model_fit = model.fit(disp=False)

        # Forecast for the test period
        n_test = len(y_test)
        forecast = model_fit.forecast(steps=n_test, exog=exog_test)
        y_pred = forecast.values

        # Sla de eerste 24 uur over
        if len(y_pred) > 24:
            y_pred = y_pred[24:]
            y_test = y_test[24:]
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan
            rmse_results.append({
                'iteration': i + 1,
                'run_date': run_date.strftime('%Y-%m-%d'),
                'valid_predictions': 0,
                'rmse': rmse
            })
            continue

        if len(y_pred) > 0:
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            rmse = np.nan

        print(f"RSME is {rmse:.4f} for day {i+1}")

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(y_pred),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(y_pred)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - SARIMAX Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-06-01 04:37:54,343 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-06-01 04:37:54,357 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 04:37:54,359 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 🔍 Testing SARIMAX Model - RMSE per forecast day
# ============================================================
# 2025-06-01 04:37:54,373 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-06-01 04:53:57,871 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 04:53:57,873 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 04:53:57,874 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:53:57,889 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 04:53:57,890 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 04:53:57,896 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 04:53:57,898 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:53:57,902 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 04:53:57,903 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 04:53:57,903 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 04:53:57,904 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 04:53:57,904 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 04:53:57,938 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 04:53:57,939 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 04:53:57,970 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 04:53:57,971 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 04:53:57,999 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 04:53:57,999 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 04:53:58,000 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 04:53:58,002 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 04:53:58,018 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 04:53:58,018 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 04:53:58,019 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 04:53:58,022 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 04:53:58,023 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 04:53:58,023 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 04:53:58,023 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-06-01 04:53:58,024 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 04:53:58,025 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 04:53:58,033 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 04:53:58,034 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 08:00:29,763 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-06-01 08:00:29,782 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 08:00:29,808 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-06-01 08:00:29,809 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-06-01 08:00:29,813 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 08:00:29,815 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 08:00:29,815 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 08:00:29,833 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 08:00:29,833 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 08:00:29,907 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 08:00:29,908 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 08:00:29,911 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 08:00:29,913 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 08:00:29,913 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 08:00:29,914 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 08:00:29,914 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 08:00:29,962 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 08:00:29,963 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# RSME is 0.0759 for day 1
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-06-01 08:00:30,003 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 08:00:30,004 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 08:00:30,031 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 08:00:30,032 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 08:00:30,032 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 08:00:30,034 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 08:00:30,047 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 08:00:30,047 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 08:00:30,049 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 08:00:30,051 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 08:00:30,051 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 08:00:30,051 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 08:00:30,052 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-06-01 08:00:30,052 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 08:00:30,053 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 08:00:30,062 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 08:00:30,063 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:13:22,873 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-06-01 09:13:22,885 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:13:22,886 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-06-01 09:13:22,886 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-06-01 09:13:22,888 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:13:22,890 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:13:22,890 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:22,923 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:13:22,933 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:13:22,937 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:13:22,939 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:22,943 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:13:22,943 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:13:22,944 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:13:22,944 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:13:22,945 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:13:22,986 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:13:23,019 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:13:23,047 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:13:23,048 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# RSME is 0.0475 for day 2
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-06-01 09:13:23,084 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:13:23,085 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:13:23,085 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:13:23,087 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:13:23,098 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:13:23,099 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:13:23,100 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:13:23,101 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:13:23,101 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:13:23,101 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:23,102 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-06-01 09:13:23,102 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:13:23,103 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:13:23,130 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:13:23,131 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:13:59,297 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-06-01 09:13:59,298 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:13:59,298 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-06-01 09:13:59,299 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-06-01 09:13:59,299 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:13:59,301 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:13:59,302 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:59,318 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:13:59,320 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:13:59,327 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:13:59,332 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:59,337 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:13:59,337 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:13:59,338 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:13:59,339 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:13:59,339 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:13:59,376 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:13:59,377 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:13:59,424 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:13:59,430 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:13:59,474 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:13:59,476 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:13:59,476 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:13:59,479 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:13:59,495 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# RSME is 0.0744 for day 3
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-06-01 09:13:59,499 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:13:59,501 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:13:59,503 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:13:59,506 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:13:59,507 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:13:59,509 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-06-01 09:13:59,519 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:13:59,530 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:13:59,542 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:13:59,543 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:14:59,540 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-06-01 09:14:59,602 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:14:59,641 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-06-01 09:14:59,645 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-06-01 09:14:59,648 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:14:59,649 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:14:59,650 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:14:59,678 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:14:59,678 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:14:59,683 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:14:59,685 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:14:59,688 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:14:59,689 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:14:59,689 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:14:59,690 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:14:59,690 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:14:59,733 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:14:59,735 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:14:59,769 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:14:59,770 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# RSME is 0.0374 for day 4
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-06-01 09:14:59,805 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:14:59,806 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:14:59,806 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:14:59,809 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:14:59,823 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:14:59,824 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:14:59,825 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:14:59,827 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:14:59,828 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:14:59,828 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:14:59,829 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-06-01 09:14:59,829 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:14:59,830 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:14:59,838 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:14:59,839 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:15:59,888 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-06-01 09:15:59,899 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:15:59,900 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-06-01 09:15:59,900 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-06-01 09:15:59,901 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:15:59,905 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:15:59,907 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:15:59,942 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:15:59,949 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:15:59,956 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:15:59,958 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:15:59,966 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:15:59,966 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:15:59,967 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:15:59,967 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:15:59,968 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:16:00,005 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:16:00,024 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:16:00,050 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:16:00,052 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:16:00,075 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:16:00,077 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:16:00,080 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:16:00,083 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# RSME is 0.0369 for day 5
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-06-01 09:16:00,108 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:16:00,109 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:16:00,111 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:16:00,115 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:16:00,116 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:16:00,117 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:16:00,117 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-06-01 09:16:00,117 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:16:00,118 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:16:00,125 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:16:00,126 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:17:00,218 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-06-01 09:17:00,228 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:17:00,230 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-06-01 09:17:00,231 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-06-01 09:17:00,232 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:17:00,234 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:17:00,235 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:00,253 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:17:00,254 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:17:00,259 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:17:00,260 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:00,263 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:17:00,264 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:17:00,265 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:17:00,266 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:17:00,266 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:17:00,337 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:17:00,349 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:17:00,377 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:17:00,378 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:17:00,405 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:17:00,406 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:17:00,408 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:17:00,410 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# RSME is 0.0450 for day 6
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-06-01 09:17:00,425 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:17:00,426 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:17:00,428 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:17:00,430 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:17:00,431 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:17:00,432 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:00,433 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-06-01 09:17:00,433 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:17:00,435 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:17:00,445 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:17:00,445 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:17:58,962 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-06-01 09:17:58,963 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:17:58,964 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-06-01 09:17:58,965 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-06-01 09:17:58,966 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:17:58,967 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:17:58,968 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:58,985 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:17:58,997 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:17:59,022 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:17:59,024 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:59,032 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:17:59,032 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:17:59,033 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:17:59,033 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:17:59,034 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:17:59,080 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:17:59,080 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:17:59,108 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:17:59,108 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:17:59,142 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:17:59,144 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:17:59,144 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:17:59,147 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:17:59,170 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# RSME is 0.0466 for day 7
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-06-01 09:17:59,172 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:17:59,173 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:17:59,175 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:17:59,176 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:17:59,176 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:17:59,176 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-06-01 09:17:59,177 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:17:59,178 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:17:59,185 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:17:59,186 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:18:58,544 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-06-01 09:18:58,545 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:18:58,550 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-06-01 09:18:58,560 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-06-01 09:18:58,561 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:18:58,563 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:18:58,563 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:18:58,574 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:18:58,574 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:18:58,582 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:18:58,584 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:18:58,591 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:18:58,591 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:18:58,592 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:18:58,592 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:18:58,593 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:18:58,667 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:18:58,668 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:18:58,705 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:18:58,706 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:18:58,738 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:18:58,742 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# RSME is 0.2150 for day 8
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-06-01 09:18:58,746 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:18:58,750 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:18:58,782 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:18:58,782 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:18:58,783 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:18:58,784 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:18:58,785 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:18:58,785 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:18:58,786 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-06-01 09:18:58,786 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:18:58,787 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:18:58,794 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:18:58,795 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:23:23,999 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-06-01 09:23:24,000 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:23:24,003 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-06-01 09:23:24,003 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-06-01 09:23:24,004 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:23:24,007 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:23:24,008 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:23:24,024 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:23:24,025 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:23:24,098 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:23:24,100 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:23:24,107 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:23:24,108 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:23:24,109 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:23:24,109 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:23:24,110 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:23:24,166 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:23:24,167 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:23:24,196 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:23:24,196 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# RSME is 0.0313 for day 9
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-06-01 09:23:24,220 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:23:24,220 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:23:24,220 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:23:24,222 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:23:24,234 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:23:24,235 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:23:24,236 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:23:24,237 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:23:24,237 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:23:24,237 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:23:24,238 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-06-01 09:23:24,238 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:23:24,239 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:23:24,247 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:23:24,248 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:24:26,607 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-06-01 09:24:26,608 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:24:26,608 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-06-01 09:24:26,609 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-06-01 09:24:26,610 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:24:26,612 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:24:26,613 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:24:26,626 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# ...
# 2025-06-01 09:56:18,739 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-06-01 09:56:18,764 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:56:18,765 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-06-01 09:56:18,766 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-06-01 09:56:18,767 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:56:18,768 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:56:18,769 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:18,780 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:56:18,781 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:56:18,795 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:56:18,798 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:18,801 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:56:18,804 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:56:18,804 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:56:18,805 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:56:18,806 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:56:18,871 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:56:18,892 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:56:18,932 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:56:18,933 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# RSME is 0.0271 for day 27
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-06-01 09:56:18,960 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:56:18,962 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:56:18,962 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:56:18,965 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:56:18,980 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:56:18,980 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:56:18,981 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:56:18,983 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:56:18,983 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:56:18,984 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:18,984 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-06-01 09:56:18,984 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:56:18,985 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:56:18,992 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:56:18,992 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:56:48,071 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-06-01 09:56:48,089 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:56:48,090 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-06-01 09:56:48,091 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-06-01 09:56:48,091 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:56:48,092 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:56:48,093 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:48,103 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:56:48,104 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:56:48,109 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:56:48,111 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:48,121 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:56:48,121 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:56:48,122 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:56:48,123 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:56:48,123 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:56:48,157 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:56:48,163 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:56:48,229 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:56:48,230 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:56:48,256 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:56:48,257 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:56:48,258 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:56:48,261 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:56:48,285 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:56:48,285 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:56:48,287 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# RSME is 0.0286 for day 28
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-06-01 09:56:48,290 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:56:48,291 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:56:48,291 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:56:48,291 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-06-01 09:56:48,292 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:56:48,293 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:56:48,300 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:56:48,301 - build_training_set - INFO - 🔒 Connection closed
# 2025-06-01 09:57:21,225 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-06-01 09:57:21,227 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-06-01 09:57:21,227 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-06-01 09:57:21,229 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-06-01 09:57:21,230 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-06-01 09:57:21,232 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-06-01 09:57:21,233 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:57:21,248 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-06-01 09:57:21,249 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-06-01 09:57:21,256 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-06-01 09:57:21,258 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:57:21,265 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-06-01 09:57:21,266 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-06-01 09:57:21,266 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-06-01 09:57:21,267 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-06-01 09:57:21,267 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-06-01 09:57:21,330 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-06-01 09:57:21,330 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-06-01 09:57:21,367 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-06-01 09:57:21,367 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-06-01 09:57:21,398 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-06-01 09:57:21,400 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-06-01 09:57:21,401 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-06-01 09:57:21,403 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-06-01 09:57:21,418 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-06-01 09:57:21,419 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-06-01 09:57:21,421 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-06-01 09:57:21,423 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-06-01 09:57:21,424 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-06-01 09:57:21,424 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-06-01 09:57:21,425 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# RSME is 0.0326 for day 29
# Day 29: ✅ 144 test rows, Run: 04-12
# 2025-06-01 09:57:21,425 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-06-01 09:57:21,429 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-06-01 09:57:21,440 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-06-01 09:57:21,441 - build_training_set - INFO - 🔒 Connection closed
# RSME is 0.0641 for day 30
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - SARIMAX Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.08
#          2 2025-03-16                144  0.05
#          3 2025-03-17                144  0.07
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.05
#          8 2025-03-22                144  0.22
#          9 2025-03-23                144  0.03
#         10 2025-03-24                144  0.07
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.04
#         13 2025-03-27                144  0.06
#         14 2025-03-28                144  0.06
#         15 2025-03-29                144  0.08
#         16 2025-03-30                144  0.21
#         17 2025-03-31                144  0.06
#         18 2025-04-01                144  0.06
#         19 2025-04-02                144  0.05
#         20 2025-04-03                144  0.09
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.09
#         24 2025-04-07                144  0.02
#         25 2025-04-08                144  0.04
#         26 2025-04-09                144  0.03
#         27 2025-04-10                144  0.03
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.06
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.06
# std       0.05
# min       0.02
# 25%       0.03
# 50%       0.05
# 75%       0.07
# max       0.22
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0603
# Stddev RMSE: 0.0452
