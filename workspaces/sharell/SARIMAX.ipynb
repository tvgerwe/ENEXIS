# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing SARIMA Model - RMSE per forecast day")
print("=" * 60)

# SARIMA parameters (example: adjust as needed)
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 24)  # 24 for hourly data with daily seasonality

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df['target_datetime'] <= run_date_utc]
        test_data = df[df['target_datetime'] > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=['target_datetime', target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Prepare data for SARIMA
        # Zorg dat index datetime64[ns] en zonder tz is
        train_data['target_datetime'] = pd.to_datetime(train_data['target_datetime']).dt.tz_localize(None)
        test_data['target_datetime'] = pd.to_datetime(test_data['target_datetime']).dt.tz_localize(None)
        y_train = train_data.set_index('target_datetime')[target].astype(float)
        y_test = test_data.set_index('target_datetime')[target].astype(float)

        # Fit SARIMA model
        model = SARIMAX(y_train, order=order, seasonal_order=seasonal_order, enforce_stationarity=False, enforce_invertibility=False)
        model_fit = model.fit(disp=False)

        # Forecast for the test period
        n_test = len(y_test)
        forecast = model_fit.forecast(steps=n_test)
        y_pred = forecast.values

        # Sla de eerste 24 uur over
        if len(y_pred) > 24:
            y_pred = y_pred[24:]
            y_test = y_test[24:]
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan
            rmse_results.append({
                'iteration': i + 1,
                'run_date': run_date.strftime('%Y-%m-%d'),
                'valid_predictions': 0,
                'rmse': rmse
            })
            continue

        if len(y_pred) > 0:
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(y_pred),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(y_pred)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - SARIMA Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-30 16:02:22,540 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-30 16:02:22,543 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:02:22,544 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-30 16:02:22,547 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:02:22,552 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:02:22,559 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:02:22,559 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:22,675 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:02:22,675 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:02:22,694 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:02:22,694 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:22,729 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 🔍 Testing SARIMA Model - RMSE per forecast day
# ============================================================
# 2025-05-30 16:02:22,735 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:02:22,735 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:02:22,735 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:02:22,735 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:02:22,853 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:02:22,853 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:02:22,955 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:02:22,956 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:02:23,076 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:02:23,078 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:02:23,078 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:02:23,087 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:02:23,176 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:02:23,176 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:02:23,187 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:02:23,191 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:02:23,191 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:02:23,199 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:23,204 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:02:23,204 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:02:23,214 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:02:23,302 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:02:23,305 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:02:45,585 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-30 16:02:45,593 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:02:45,593 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-30 16:02:45,593 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 16:02:45,595 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:02:45,595 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:02:45,595 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:45,646 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:02:45,652 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:02:45,670 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:02:45,670 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:45,687 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:02:45,695 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:02:45,697 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:02:45,697 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:02:45,702 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:02:45,767 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-30 16:02:45,769 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:02:45,849 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:02:45,853 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:02:45,925 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:02:45,925 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:02:45,930 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:02:45,938 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:02:45,976 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:02:45,978 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:02:45,982 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:02:45,987 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:02:45,994 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:02:45,995 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:02:45,998 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 16:02:46,003 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:02:46,008 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:02:46,074 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:02:46,075 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:03:02,858 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-30 16:03:02,868 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:03:02,868 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-30 16:03:02,877 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 16:03:02,885 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:03:02,900 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:03:02,902 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:03,035 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:03:03,043 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-05-30 16:03:03,370 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:03:03,379 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:03,417 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:03:03,417 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:03:03,417 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:03:03,425 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:03:03,425 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:03:03,570 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:03:03,570 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:03:03,707 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:03:03,717 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:03:03,861 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:03:03,867 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:03:03,867 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:03:03,876 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:03:03,951 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:03:03,955 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:03:03,963 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:03:03,963 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:03:03,971 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:03:03,971 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:03,971 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 16:03:03,982 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:03:03,986 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:03:04,107 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:03:04,107 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:03:19,252 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-05-30 16:03:19,252 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:03:19,252 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-05-30 16:03:19,252 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 16:03:19,266 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:03:19,269 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:03:19,269 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:19,323 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:03:19,323 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:03:19,341 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:03:19,341 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:19,382 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:03:19,390 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:03:19,393 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:03:19,396 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:03:19,398 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-05-30 16:03:19,530 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:03:19,532 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:03:19,664 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:03:19,665 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:03:19,747 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:03:19,747 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:03:19,747 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:03:19,753 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:03:19,806 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:03:19,806 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:03:19,806 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:03:19,814 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:03:19,814 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:03:19,822 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:19,822 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 16:03:19,822 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:03:19,831 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:03:19,905 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:03:19,905 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:03:35,940 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-05-30 16:03:35,940 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:03:35,940 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-05-30 16:03:35,944 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 16:03:35,946 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:03:35,946 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:03:35,946 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:36,005 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:03:36,005 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:03:36,021 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:03:36,021 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:36,044 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:03:36,044 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:03:36,053 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:03:36,053 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:03:36,053 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-05-30 16:03:36,161 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:03:36,161 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:03:36,303 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:03:36,313 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:03:36,483 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:03:36,496 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:03:36,504 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:03:36,514 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:03:36,550 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:03:36,550 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:03:36,558 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:03:36,562 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:03:36,562 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:03:36,562 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:36,562 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 16:03:36,562 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:03:36,570 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:03:36,647 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:03:36,648 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:03:51,040 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-05-30 16:03:51,040 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:03:51,040 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-05-30 16:03:51,048 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 16:03:51,050 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:03:51,050 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:03:51,050 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:51,092 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:03:51,100 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:03:51,124 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:03:51,124 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:51,150 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:03:51,150 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:03:51,150 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:03:51,156 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:03:51,158 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:03:51,215 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:03:51,215 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-05-30 16:03:51,284 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:03:51,290 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:03:51,400 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:03:51,402 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:03:51,402 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:03:51,407 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:03:51,457 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:03:51,457 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:03:51,466 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:03:51,473 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:03:51,475 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:03:51,475 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:03:51,475 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 16:03:51,475 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:03:51,483 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:03:51,566 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:03:51,566 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:04:03,404 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:04:03,412 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:03,460 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:04:03,460 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:04:03,475 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:04:03,475 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:03,508 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:04:03,508 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:04:03,508 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:04:03,508 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:04:03,508 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:04:03,585 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-05-30 16:04:03,585 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:04:03,701 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:04:03,701 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:04:03,896 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:04:03,896 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:04:03,902 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:04:03,903 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:04:03,962 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:04:03,970 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:04:03,970 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:04:03,970 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:04:03,970 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:04:03,978 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:03,978 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 16:04:03,978 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:04:03,985 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:04:04,044 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:04:04,044 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:04:17,447 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-05-30 16:04:17,447 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:04:17,455 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-05-30 16:04:17,455 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 16:04:17,455 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:04:17,464 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:04:17,464 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:17,529 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:04:17,529 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:04:17,538 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:04:17,545 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:17,564 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:04:17,572 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:04:17,572 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:04:17,572 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:04:17,572 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-05-30 16:04:17,645 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:04:17,648 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:04:17,739 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:04:17,746 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:04:17,822 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:04:17,831 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:04:17,831 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:04:17,831 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:04:17,879 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:04:17,887 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:04:17,887 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:04:17,898 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:04:17,898 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:04:17,898 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:17,907 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 16:04:17,907 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:04:17,914 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:04:17,983 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:04:17,983 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:04:33,728 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:33,801 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:04:33,801 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:04:33,834 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:04:33,834 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:33,861 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:04:33,861 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:04:33,869 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:04:33,869 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:04:33,869 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-05-30 16:04:34,027 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:04:34,055 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:04:34,184 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:04:34,184 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:04:34,310 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:04:34,310 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:04:34,310 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:04:34,317 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:04:34,387 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:04:34,392 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:04:34,395 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:04:34,400 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:04:34,400 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:04:34,400 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:34,408 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 16:04:34,412 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:04:34,417 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:04:34,494 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:04:34,494 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:04:43,127 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-05-30 16:04:43,135 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:04:43,136 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-05-30 16:04:43,136 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 16:04:43,140 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:04:43,142 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:04:43,142 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:43,193 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:04:43,193 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:04:43,210 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:04:43,220 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:43,236 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:04:43,244 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:04:43,244 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:04:43,244 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:04:43,244 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-05-30 16:04:43,370 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:04:43,370 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:04:43,484 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:04:43,484 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:04:43,593 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:04:43,600 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:04:43,602 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:04:43,610 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:04:43,683 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:04:43,685 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:04:43,685 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:04:43,685 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:04:43,694 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:04:43,694 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:43,694 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 16:04:43,701 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:04:43,703 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:04:43,794 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:04:43,801 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:04:56,832 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:04:56,836 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:04:56,896 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:04:56,898 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:04:56,916 - build_training_set - INFO - 📊 Forecast rows available: 169
# ...
# 2025-05-30 16:08:29,291 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:08:50,640 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-05-30 16:08:50,648 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:08:50,649 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-05-30 16:08:50,650 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 16:08:50,650 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:08:50,650 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:08:50,650 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:08:50,693 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:08:50,693 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:08:50,709 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:08:50,709 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:08:50,727 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:08:50,727 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:08:50,727 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:08:50,727 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:08:50,736 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:08:50,788 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:08:50,790 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-05-30 16:08:50,853 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:08:50,853 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:08:50,951 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:08:50,951 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:08:50,951 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:08:50,960 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:08:50,993 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:08:50,995 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:08:50,995 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:08:50,995 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:08:50,995 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:08:51,003 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:08:51,004 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 16:08:51,004 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:08:51,004 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:08:51,066 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:08:51,066 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:09:02,419 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-05-30 16:09:02,419 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:09:02,419 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-05-30 16:09:02,419 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 16:09:02,419 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:09:02,428 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:09:02,428 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:02,484 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:09:02,484 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:09:02,502 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:09:02,510 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:02,535 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:09:02,535 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:09:02,544 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:09:02,544 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:09:02,544 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-05-30 16:09:02,674 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:09:02,690 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:09:02,809 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:09:02,809 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:09:02,860 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:09:02,868 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:09:02,868 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:09:02,868 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:09:02,918 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:09:02,918 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:09:02,935 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:09:02,935 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:09:02,944 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:09:02,944 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:02,944 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 16:09:02,952 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:09:02,960 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:09:03,035 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:09:03,035 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:09:19,714 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:09:19,716 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:19,767 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:09:19,767 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:09:19,791 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:09:19,799 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:19,818 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:09:19,827 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:09:19,827 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:09:19,829 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:09:19,829 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 16:09:19,884 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:09:19,893 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# Day 29: ✅ 144 test rows, Run: 04-12
# 2025-05-30 16:09:19,963 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:09:19,963 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:09:20,035 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:09:20,035 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:09:20,043 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:09:20,045 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:09:20,080 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:09:20,089 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:09:20,089 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:09:20,089 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:09:20,089 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:09:20,089 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:09:20,089 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 16:09:20,097 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:09:20,097 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:09:20,158 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:09:20,158 - build_training_set - INFO - 🔒 Connection closed
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - SARIMA Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.05
#          2 2025-03-16                144  0.04
#          3 2025-03-17                144  0.06
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.05
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.12
#          9 2025-03-23                144  0.02
#         10 2025-03-24                144  0.05
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.05
#         13 2025-03-27                144  0.05
#         14 2025-03-28                144  0.04
#         15 2025-03-29                144  0.06
#         16 2025-03-30                144  0.11
#         17 2025-03-31                144  0.04
#         18 2025-04-01                144  0.05
#         19 2025-04-02                144  0.04
#         20 2025-04-03                144  0.04
#         21 2025-04-04                144  0.05
#         22 2025-04-05                144  0.03
#         23 2025-04-06                144  0.05
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.03
#         26 2025-04-09                144  0.03
#         27 2025-04-10                144  0.03
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.04
#         30 2025-04-13                144  0.04
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.05
# std       0.02
# min       0.02
# 25%       0.04
# 50%       0.04
# 75%       0.05
# max       0.12
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0454
# Stddev RMSE: 0.0207

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

FEATURES = [
    'Load', 'shortwave_radiation', 'temperature_2m', 
    'direct_normal_irradiance', 'diffuse_radiation', 
    'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 
    'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 
    'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 
    'hour_sin', 'weekday_cos'
]
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing SARIMAX Model - RMSE per forecast day")
print("=" * 60)

# SARIMAX parameters (example: adjust as needed)
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 24)  # 24 for hourly data with daily seasonality

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df['target_datetime'] <= run_date_utc]
        test_data = df[df['target_datetime'] > run_date_utc]

        # Drop any missing data in training and test
        train_data = train_data.dropna(subset=['target_datetime', target] + FEATURES)
        test_data = test_data.dropna(subset=['target_datetime', target] + FEATURES)

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Prepare data for SARIMAX
        train_data['target_datetime'] = pd.to_datetime(train_data['target_datetime']).dt.tz_localize(None)
        test_data['target_datetime'] = pd.to_datetime(test_data['target_datetime']).dt.tz_localize(None)
        y_train = train_data.set_index('target_datetime')[target].astype(float)
        y_test = test_data.set_index('target_datetime')[target].astype(float)
        exog_train = train_data.set_index('target_datetime')[FEATURES].astype(float)
        exog_test = test_data.set_index('target_datetime')[FEATURES].astype(float)

        # Fit SARIMAX model with exogenous variables
        model = SARIMAX(
            y_train,
            exog=exog_train,
            order=order,
            seasonal_order=seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        model_fit = model.fit(disp=False)

        # Forecast for the test period
        n_test = len(y_test)
        forecast = model_fit.forecast(steps=n_test, exog=exog_test)
        y_pred = forecast.values

        # Sla de eerste 24 uur over
        if len(y_pred) > 24:
            y_pred = y_pred[24:]
            y_test = y_test[24:]
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan
            rmse_results.append({
                'iteration': i + 1,
                'run_date': run_date.strftime('%Y-%m-%d'),
                'valid_predictions': 0,
                'rmse': rmse
            })
            continue

        if len(y_pred) > 0:
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            rmse = np.nan

        print(f"RSME is {rmse:.4f} for day {i+1}")

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(y_pred),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(y_pred)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - SARIMAX Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-30 16:46:13,285 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-30 16:46:13,285 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:46:13,285 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-30 16:46:13,285 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:46:13,285 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:46:13,312 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:46:13,312 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:46:13,413 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:46:13,413 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:46:13,429 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:46:13,432 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:46:13,446 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:46:13,450 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:46:13,450 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:46:13,450 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:46:13,450 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 🔍 Testing SARIMAX Model - RMSE per forecast day
# ============================================================
# 2025-05-30 16:46:13,538 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:46:13,538 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:46:13,613 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:46:13,613 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:46:13,696 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:46:13,713 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:46:13,713 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:46:13,713 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:46:13,786 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:46:13,790 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:46:13,790 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:46:13,796 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:46:13,804 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:46:13,808 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:46:13,813 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 16:46:13,815 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:46:13,822 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:46:13,879 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:46:13,881 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:49:21,411 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-30 16:49:21,411 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:49:21,411 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-30 16:49:21,411 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 16:49:21,411 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:49:21,426 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:49:21,426 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:49:21,529 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:49:21,529 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:49:21,547 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:49:21,547 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:49:21,571 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:49:21,571 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:49:21,571 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:49:21,571 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:49:21,578 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0759 for day 1
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-30 16:49:21,705 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:49:21,705 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:49:21,805 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:49:21,805 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:49:21,888 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:49:21,888 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:49:21,888 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:49:21,904 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:49:21,946 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:49:21,946 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:49:21,946 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:49:21,957 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:49:21,960 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:49:21,960 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:49:21,963 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 16:49:21,963 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:49:21,963 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:49:22,023 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:49:22,023 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:55:35,236 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-30 16:55:35,236 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:55:35,244 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-30 16:55:35,244 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 16:55:35,244 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:55:35,247 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:55:35,252 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:55:35,329 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:55:35,329 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:55:35,353 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:55:35,360 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:55:35,403 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:55:35,408 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:55:35,408 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:55:35,408 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:55:35,415 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0475 for day 2
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-05-30 16:55:35,537 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:55:35,545 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:55:35,670 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:55:35,678 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:55:35,807 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:55:35,820 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:55:35,820 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:55:35,824 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:55:35,888 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:55:35,890 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:55:35,895 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:55:35,897 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:55:35,905 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:55:35,907 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:55:35,907 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 16:55:35,907 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:55:35,922 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:55:36,002 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:55:36,003 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:57:29,000 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-05-30 16:57:29,001 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:57:29,004 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-05-30 16:57:29,007 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 16:57:29,011 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:57:29,016 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:57:29,016 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:57:29,090 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:57:29,090 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:57:29,124 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:57:29,127 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:57:29,153 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:57:29,162 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:57:29,163 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:57:29,165 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:57:29,169 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0744 for day 3
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-05-30 16:57:29,360 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:57:29,362 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:57:29,568 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:57:29,570 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:57:29,748 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:57:29,751 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:57:29,751 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:57:29,755 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:57:29,816 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:57:29,821 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:57:29,821 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:57:29,828 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:57:29,833 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:57:29,833 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:57:29,840 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 16:57:29,843 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:57:29,852 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:57:29,939 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:57:29,942 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 16:59:16,064 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-05-30 16:59:16,064 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 16:59:16,064 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-05-30 16:59:16,064 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 16:59:16,072 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 16:59:16,072 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 16:59:16,072 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:59:16,148 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 16:59:16,154 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 16:59:16,174 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 16:59:16,183 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:59:16,219 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 16:59:16,219 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 16:59:16,219 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 16:59:16,219 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 16:59:16,219 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0374 for day 4
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-05-30 16:59:16,355 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 16:59:16,355 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 16:59:16,466 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 16:59:16,474 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 16:59:16,587 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 16:59:16,587 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 16:59:16,595 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 16:59:16,603 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 16:59:16,659 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 16:59:16,667 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 16:59:16,667 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 16:59:16,675 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 16:59:16,675 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 16:59:16,675 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 16:59:16,684 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 16:59:16,684 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 16:59:16,695 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 16:59:16,765 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 16:59:16,767 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:01:01,804 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-05-30 17:01:01,804 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:01:01,812 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-05-30 17:01:01,812 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 17:01:01,815 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:01:01,815 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:01:01,815 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:01:01,893 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 17:01:01,893 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 17:01:01,937 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 17:01:01,942 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:01:01,968 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 17:01:01,977 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 17:01:01,977 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 17:01:01,977 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 17:01:01,985 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0369 for day 5
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-05-30 17:01:02,110 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 17:01:02,110 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 17:01:02,224 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 17:01:02,232 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 17:01:02,350 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 17:01:02,350 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 17:01:02,359 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 17:01:02,367 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 17:01:02,419 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 17:01:02,419 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 17:01:02,427 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 17:01:02,427 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 17:01:02,435 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 17:01:02,437 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:01:02,437 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 17:01:02,437 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 17:01:02,445 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 17:01:02,529 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 17:01:02,537 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:02:48,646 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-05-30 17:02:48,646 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:02:48,646 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-05-30 17:02:48,646 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 17:02:48,646 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:02:48,655 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:02:48,655 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:02:48,758 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 17:02:48,758 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 17:02:48,791 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 17:02:48,796 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:02:48,820 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 17:02:48,828 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 17:02:48,828 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 17:02:48,828 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 17:02:48,828 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0450 for day 6
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-05-30 17:02:48,973 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 17:02:48,975 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 17:02:49,107 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 17:02:49,107 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 17:02:49,224 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 17:02:49,224 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 17:02:49,224 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 17:02:49,232 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 17:02:49,290 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 17:02:49,290 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 17:02:49,298 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 17:02:49,298 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 17:02:49,309 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 17:02:49,312 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:02:49,315 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 17:02:49,317 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 17:02:49,321 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 17:02:49,393 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 17:02:49,393 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:04:35,798 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-05-30 17:04:35,798 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:04:35,798 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-05-30 17:04:35,806 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 17:04:35,806 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:04:35,816 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:04:35,816 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:04:35,889 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 17:04:35,889 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 17:04:35,922 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 17:04:35,922 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:04:35,955 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 17:04:35,955 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 17:04:35,955 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 17:04:35,955 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 17:04:35,955 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0466 for day 7
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-05-30 17:04:36,091 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 17:04:36,091 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 17:04:36,216 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 17:04:36,216 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 17:04:36,341 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 17:04:36,341 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 17:04:36,341 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 17:04:36,349 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 17:04:36,417 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 17:04:36,417 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 17:04:36,425 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 17:04:36,425 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 17:04:36,433 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 17:04:36,433 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:04:36,433 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 17:04:36,441 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 17:04:36,449 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 17:04:36,521 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 17:04:36,521 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:06:23,836 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-05-30 17:06:23,839 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:06:23,840 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-05-30 17:06:23,841 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 17:06:23,843 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:06:23,844 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:06:23,844 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:06:23,917 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 17:06:23,917 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 17:06:23,942 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 17:06:23,950 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:06:23,977 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 17:06:23,986 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 17:06:23,986 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 17:06:23,986 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 17:06:23,986 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.2150 for day 8
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-05-30 17:06:24,121 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 17:06:24,121 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 17:06:24,235 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 17:06:24,244 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 17:06:24,352 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 17:06:24,361 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 17:06:24,361 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 17:06:24,369 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 17:06:24,438 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 17:06:24,446 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 17:06:24,446 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 17:06:24,455 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 17:06:24,458 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 17:06:24,460 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:06:24,464 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 17:06:24,465 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 17:06:24,474 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 17:06:24,534 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 17:06:24,543 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:08:20,181 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-05-30 17:08:20,189 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:08:20,189 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-05-30 17:08:20,189 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 17:08:20,189 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:08:20,197 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:08:20,197 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:08:20,265 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 17:08:20,273 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 17:08:20,297 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 17:08:20,297 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:08:20,330 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 17:08:20,330 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 17:08:20,338 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 17:08:20,340 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 17:08:20,340 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0313 for day 9
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-05-30 17:08:20,510 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 17:08:20,517 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 17:08:20,651 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 17:08:20,651 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 17:08:20,772 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 17:08:20,772 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 17:08:20,780 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 17:08:20,788 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 17:08:20,845 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 17:08:20,845 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 17:08:20,845 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 17:08:20,858 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 17:08:20,861 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 17:08:20,864 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:08:20,866 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 17:08:20,866 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 17:08:20,872 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 17:08:20,953 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 17:08:20,953 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 17:10:19,273 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-05-30 17:10:19,282 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 17:10:19,282 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-05-30 17:10:19,282 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-05-30 17:10:19,282 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 17:10:19,290 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 17:10:19,290 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 17:10:19,364 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# ...
# 2025-05-30 18:52:51,622 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-05-30 18:52:51,622 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 18:52:51,630 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-05-30 18:52:51,630 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 18:52:51,630 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 18:52:51,638 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 18:52:51,638 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:52:51,722 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 18:52:51,722 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 18:52:51,755 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 18:52:51,755 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:52:51,788 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# RSME is 0.0271 for day 27
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-05-30 18:52:51,808 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 18:52:51,816 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 18:52:51,816 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 18:52:51,824 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 18:52:51,947 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 18:52:51,955 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 18:52:52,074 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 18:52:52,074 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 18:52:52,183 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 18:52:52,191 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 18:52:52,204 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 18:52:52,207 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 18:52:52,265 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 18:52:52,274 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 18:52:52,284 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 18:52:52,284 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 18:52:52,292 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 18:52:52,292 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:52:52,292 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 18:52:52,300 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 18:52:52,308 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 18:52:53,217 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 18:52:53,220 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 18:53:40,722 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-05-30 18:53:40,724 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 18:53:40,726 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-05-30 18:53:40,727 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 18:53:40,727 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 18:53:40,733 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 18:53:40,733 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:53:40,816 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 18:53:40,825 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 18:53:40,850 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 18:53:40,858 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:53:40,882 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 18:53:40,882 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 18:53:40,889 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 18:53:40,892 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 18:53:40,892 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0286 for day 28
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-05-30 18:53:41,019 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 18:53:41,019 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 18:53:41,142 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 18:53:41,142 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 18:53:41,259 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 18:53:41,268 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 18:53:41,268 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 18:53:41,276 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 18:53:41,341 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 18:53:41,341 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 18:53:41,350 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 18:53:41,356 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 18:53:41,357 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 18:53:41,357 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:53:41,364 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 18:53:41,364 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 18:53:41,376 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 18:53:41,435 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 18:53:41,444 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 18:54:37,660 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-05-30 18:54:37,660 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 18:54:37,660 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-05-30 18:54:37,668 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 18:54:37,668 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 18:54:37,676 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 18:54:37,676 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:54:37,755 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 18:54:37,755 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 18:54:37,781 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 18:54:37,792 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:54:37,824 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 18:54:37,827 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 18:54:37,827 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 18:54:37,827 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 18:54:37,827 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# RSME is 0.0326 for day 29
# Day 29: ✅ 144 test rows, Run: 04-12
# 2025-05-30 18:54:37,961 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 18:54:37,961 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 18:54:38,084 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 18:54:38,084 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 18:54:38,203 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 18:54:38,203 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 18:54:38,203 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 18:54:38,220 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 18:54:38,273 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 18:54:38,273 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 18:54:38,281 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 18:54:38,281 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 18:54:38,289 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 18:54:38,289 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 18:54:38,289 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 18:54:38,298 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 18:54:38,306 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 18:54:38,383 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 18:54:38,391 - build_training_set - INFO - 🔒 Connection closed
# RSME is 0.0641 for day 30
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - SARIMAX Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.08
#          2 2025-03-16                144  0.05
#          3 2025-03-17                144  0.07
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.05
#          8 2025-03-22                144  0.22
#          9 2025-03-23                144  0.03
#         10 2025-03-24                144  0.07
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.04
#         13 2025-03-27                144  0.06
#         14 2025-03-28                144  0.06
#         15 2025-03-29                144  0.08
#         16 2025-03-30                144  0.21
#         17 2025-03-31                144  0.06
#         18 2025-04-01                144  0.06
#         19 2025-04-02                144  0.05
#         20 2025-04-03                144  0.09
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.09
#         24 2025-04-07                144  0.02
#         25 2025-04-08                144  0.04
#         26 2025-04-09                144  0.03
#         27 2025-04-10                144  0.03
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.06
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.06
# std       0.05
# min       0.02
# 25%       0.03
# 50%       0.05
# 75%       0.07
# max       0.22
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0603
# Stddev RMSE: 0.0452
