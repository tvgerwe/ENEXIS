# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

# Define feature columns and target
FEATURES = ['weekday_cos', 'weekday_sin', 'hour_cos', 'hour_sin', 'yearday_cos', 'yearday_sin']
TRAIN_FEATURES = FEATURES
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing XGBoost Model - RMSE per forecast day")
print("=" * 60)

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Train model
        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        model = xgb.XGBRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)

        # Zorg dat alle features aanwezig zijn in test_data
        for col in TRAIN_FEATURES:
            if col not in test_data.columns:
                test_data[col] = np.nan

        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]

        # Alleen voorspellen als er nog testdata over is
        if len(X_test) > 0:
            y_pred = model.predict(X_test)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(X_test),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(X_test)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - XGBoost Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-30 15:46:19,422 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:19,422 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:19,422 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:19,431 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 15:46:19,431 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:19,431 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:19,440 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:19,533 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:19,533 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:19,565 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:19,568 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 🔍 Testing XGBoost Model - RMSE per forecast day
# ============================================================
# 2025-05-30 15:46:19,599 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:19,599 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:19,599 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:19,607 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:19,608 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:19,698 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:19,698 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:19,780 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:19,780 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:19,849 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:19,857 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:19,857 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:19,865 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:19,923 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:19,930 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:19,931 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:19,931 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:19,940 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:19,940 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:19,940 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 15:46:19,948 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:19,948 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:20,015 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:20,015 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:20,223 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:20,224 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:20,224 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:20,225 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 15:46:20,227 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:20,233 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:20,235 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:20,318 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:20,318 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:20,337 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:20,337 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:20,363 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:20,365 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:20,365 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:20,365 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:20,365 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:20,430 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-30 15:46:20,436 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:20,507 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:20,507 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:20,584 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:20,592 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:20,592 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:20,598 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:20,636 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:20,636 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:20,645 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:20,650 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:20,650 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:20,650 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:20,650 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 15:46:20,658 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:20,664 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:20,724 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:20,724 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:20,849 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:20,849 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:20,849 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:20,849 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 15:46:20,859 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:20,864 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:20,866 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:21,005 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:21,005 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:21,029 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:21,032 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-05-30 15:46:21,068 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:21,071 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:21,072 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:21,073 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:21,074 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:21,168 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:21,170 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:21,240 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:21,242 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:21,314 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:21,314 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:21,314 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:21,323 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:21,355 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:21,360 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:21,364 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:21,366 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:21,366 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:21,366 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:21,374 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 15:46:21,374 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:21,381 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:21,432 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:21,432 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:21,549 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:21,549 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:21,551 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:21,551 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 15:46:21,554 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:21,554 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:21,554 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:21,624 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:21,625 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:21,644 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:21,650 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:21,666 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:21,666 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:21,673 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:21,674 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:21,674 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:21,733 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-05-30 15:46:21,733 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:21,813 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:21,815 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:21,892 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:21,892 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:21,892 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:21,900 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:21,934 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:21,934 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:21,942 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:21,942 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:21,942 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:21,949 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:21,951 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 15:46:21,951 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:21,956 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:22,005 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:22,018 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:22,132 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:22,134 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:22,134 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:22,135 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 15:46:22,135 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:22,137 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:22,137 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:22,259 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:22,259 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:22,267 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:22,276 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:22,291 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:22,291 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:22,291 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:22,301 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:22,303 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-05-30 15:46:22,383 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:22,383 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:22,523 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:22,532 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:22,607 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:22,607 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:22,616 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:22,624 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:22,674 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:22,674 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:22,674 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:22,674 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:22,684 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:22,684 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:22,684 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 15:46:22,684 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:22,684 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:22,734 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:22,742 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:22,870 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:22,870 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:22,870 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:22,870 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 15:46:22,870 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:22,876 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:22,878 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:22,947 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:22,950 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:22,969 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:22,977 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:22,999 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:22,999 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:22,999 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:22,999 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:22,999 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:23,073 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-05-30 15:46:23,073 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:23,133 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:23,141 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:23,192 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:23,201 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:23,201 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:23,201 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:23,232 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:23,241 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:23,241 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:23,249 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:23,250 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:23,250 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:23,250 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 15:46:23,250 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:23,258 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:23,317 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:23,317 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:23,434 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:23,435 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:23,435 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:23,435 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 15:46:23,442 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:23,442 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:23,442 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:23,533 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:23,539 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:23,552 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:23,552 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:23,570 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:23,570 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:23,570 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:23,570 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:23,578 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-05-30 15:46:23,650 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:23,650 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:23,718 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:23,718 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:23,817 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:23,817 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:23,825 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:23,833 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:23,909 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:23,909 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:23,916 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:23,916 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:23,916 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:23,925 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:23,925 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 15:46:23,925 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:23,939 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:23,992 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:23,992 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:24,103 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:24,103 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:24,103 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:24,103 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 15:46:24,109 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:24,111 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:24,114 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:24,184 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:24,185 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:24,205 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:24,205 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:24,223 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:24,223 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:24,223 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:24,232 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:24,234 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:24,293 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-05-30 15:46:24,293 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:24,367 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:24,367 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:24,434 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:24,435 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:24,435 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:24,443 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:24,476 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:24,476 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:24,476 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:24,484 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:24,485 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:24,485 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:24,485 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 15:46:24,485 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:24,493 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:24,550 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:24,552 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:24,669 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:24,669 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:24,669 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:24,675 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 15:46:24,675 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:24,677 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:24,677 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:24,750 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:24,752 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:24,769 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:24,776 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:24,801 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:24,802 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:24,802 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:24,802 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:24,802 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:24,868 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-05-30 15:46:24,868 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:24,935 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:24,935 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:25,001 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:25,001 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:25,001 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:25,009 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:25,044 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:25,044 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:25,044 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:25,053 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:25,053 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:25,053 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:25,053 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 15:46:25,061 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:25,061 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:25,120 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:25,120 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:25,228 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:25,228 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:25,235 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:25,236 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 15:46:25,236 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:25,236 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:25,236 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:25,306 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:25,306 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:25,321 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:25,329 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:25,354 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:25,354 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:25,354 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:25,354 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:25,354 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:25,432 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-05-30 15:46:25,434 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:25,542 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:25,544 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:25,606 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:25,606 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:25,606 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:25,617 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:25,667 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:25,668 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:25,668 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:25,676 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:25,676 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:25,686 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:25,687 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 15:46:25,687 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:25,697 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:25,768 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:25,770 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:25,873 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:25,873 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:25,873 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:25,873 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-05-30 15:46:25,882 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:25,886 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:25,886 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:25,953 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:25,954 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:25,975 - build_training_set - INFO - 📊 Forecast rows available: 169
# ...
# 2025-05-30 15:46:37,231 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:37,386 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:37,396 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:37,465 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:37,466 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:37,483 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:37,490 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:37,516 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:37,516 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:37,516 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:37,516 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:37,516 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-05-30 15:46:37,596 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:37,596 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:37,695 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:37,697 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:37,770 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:37,770 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:37,770 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:37,783 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:37,828 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:37,828 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:37,836 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:37,836 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:37,836 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:37,836 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:37,846 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 15:46:37,847 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:37,847 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:37,924 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:37,931 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:38,046 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:38,046 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:38,046 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:38,046 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 15:46:38,046 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:38,055 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:38,055 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:38,119 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:38,119 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:38,146 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:38,149 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:38,165 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:38,165 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:38,165 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:38,175 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:38,176 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-05-30 15:46:38,273 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:46:38,279 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:38,421 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:38,421 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:38,540 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:38,546 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:38,546 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:38,554 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:38,622 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:38,622 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:38,630 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:38,638 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:38,647 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:38,647 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:38,647 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 15:46:38,656 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:38,666 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:38,752 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:38,752 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:46:38,839 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-05-30 15:46:38,839 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:46:38,839 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-05-30 15:46:38,839 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 15:46:38,839 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:46:38,847 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:46:38,847 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:38,908 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:46:38,913 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:46:38,934 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:46:38,937 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:38,955 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:46:38,957 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:46:38,957 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:46:38,957 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:46:38,957 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:46:39,028 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 29: ✅ 144 test rows, Run: 04-12
# 2025-05-30 15:46:39,028 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:46:39,171 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:46:39,171 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:46:39,305 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:46:39,314 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:46:39,314 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:46:39,330 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:46:39,396 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:46:39,396 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:46:39,405 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:46:39,405 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:46:39,414 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:46:39,414 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:46:39,414 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 15:46:39,422 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:46:39,431 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:46:39,513 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:46:39,517 - build_training_set - INFO - 🔒 Connection closed
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - XGBoost Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.05
#          2 2025-03-16                144  0.05
#          3 2025-03-17                144  0.03
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.06
#          9 2025-03-23                144  0.05
#         10 2025-03-24                144  0.04
#         11 2025-03-25                144  0.05
#         12 2025-03-26                144  0.05
#         13 2025-03-27                144  0.06
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.06
#         16 2025-03-30                144  0.05
#         17 2025-03-31                144  0.06
#         18 2025-04-01                144  0.04
#         19 2025-04-02                144  0.04
#         20 2025-04-03                144  0.04
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.02
#         23 2025-04-06                144  0.03
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.02
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.04
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.04
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.04
# 75%       0.05
# max       0.06
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0407
# Stddev RMSE: 0.0121

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import sys
from pathlib import Path

# Zorg dat build_training_set geïmporteerd is
current_dir = Path.cwd()
while current_dir.name != "ENEXIS" and current_dir.parent != current_dir:
    current_dir = current_dir.parent
project_root = current_dir
utils_path = project_root / "src" / "utils"
sys.path.append(str(utils_path))
from build_training_set import build_training_set

# Define feature columns and target
FEATURES = ['Load', 'shortwave_radiation', 'temperature_2m', 
            'direct_normal_irradiance', 'diffuse_radiation', 
            'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 
            'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 
            'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 
            'hour_sin', 'weekday_cos']
TRAIN_FEATURES = FEATURES
target = 'Price'

# Initial training window
base_start = "2025-01-01 00:00:00"
base_end = "2025-03-14 23:00:00"
base_run = "2025-03-15 00:00:00"

rmse_results = []

print("🔍 Testing XGBoost Model - RMSE per forecast day")
print("=" * 60)

for i in range(30):
    start = pd.Timestamp(base_start) + pd.Timedelta(days=i)
    end = pd.Timestamp(base_end) + pd.Timedelta(days=i)
    run_date = pd.Timestamp(base_run) + pd.Timedelta(days=i)

    try:
        df = build_training_set(
            train_start=start.strftime("%Y-%m-%d %H:%M:%S"),
            train_end=end.strftime("%Y-%m-%d %H:%M:%S"),
            run_date=run_date.strftime("%Y-%m-%d %H:%M:%S")
        )

        if df is None or df.empty:
            print(f"Day {i+1}: ❌ No training data returned")
            continue

        df['target_datetime'] = pd.to_datetime(df['target_datetime'], utc=True)
        df = df.sort_values('target_datetime').set_index('target_datetime')

        run_date_utc = run_date.tz_localize("UTC")

        # Split into training and testing sets
        train_data = df[df.index <= run_date_utc]
        test_data = df[df.index > run_date_utc]

        # Drop any missing data in training
        train_data = train_data.dropna(subset=TRAIN_FEATURES + [target])

        if test_data.empty or train_data.empty:
            print(f"Day {i+1}: ❌ Not enough data for training or testing")
            continue

        # Train model
        X_train = train_data[TRAIN_FEATURES]
        y_train = train_data[target]
        model = xgb.XGBRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)

        # Zorg dat alle features aanwezig zijn in test_data
        for col in TRAIN_FEATURES:
            if col not in test_data.columns:
                test_data[col] = np.nan

        X_test = test_data[TRAIN_FEATURES]
        y_test = test_data[target]

        # Sla de eerste 24 uur over
        X_test = X_test.iloc[24:]
        y_test = y_test.iloc[24:]

        # Alleen voorspellen als er nog testdata over is
        if len(X_test) > 0:
            y_pred = model.predict(X_test)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        else:
            print("Niet genoeg testdata na lag van 24 uur.")
            rmse = np.nan

        rmse_results.append({
            'iteration': i + 1,
            'run_date': run_date.strftime('%Y-%m-%d'),
            'valid_predictions': len(X_test),
            'rmse': rmse
        })

        print(f"Day {i+1}: ✅ {len(X_test)} test rows, Run: {run_date.strftime('%m-%d')}")

    except Exception as e:
        print(f"Day {i+1}: ❌ Error: {e}")

# Create results dataframe
if rmse_results:
    rmse_df = pd.DataFrame(rmse_results)

    print(f"\n📊 OVERALL RMSE - XGBoost Model")
    print("=" * 80)
    print(f"Successful runs: {rmse_df['rmse'].notna().sum()}/30")

    print(rmse_df[['iteration', 'run_date', 'valid_predictions', 'rmse']].round(2).to_string(index=False))

    print(f"\n📈 SUMMARY STATISTICS")
    print("-" * 40)
    print(rmse_df['rmse'].describe().round(2))

    print(f"\n📊 AVERAGE OVERALL RMSE")
    print("-" * 40)
    print(f"Mean RMSE: {rmse_df['rmse'].mean():.4f}")
    print(f"Stddev RMSE: {rmse_df['rmse'].std():.4f}")

else:
    print("❌ No runs completed successfully")
# Out:
# 2025-05-30 15:48:27,620 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-15 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:27,629 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:27,631 - build_training_set - INFO - 🧠 Actuals van 2025-01-01 00:00:00+00:00 t/m 2025-03-14 23:00:00+00:00 (extended to 2025-03-15 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:27,633 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-15 00:00:00+00:00, normalized to 2025-03-15 00:00:00+00:00 for DB lookup, target range: 2025-03-15 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 15:48:27,634 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:27,645 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:27,648 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:27,763 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:27,765 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:27,782 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:27,790 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:27,812 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 🔍 Testing XGBoost Model - RMSE per forecast day
# ============================================================
# 2025-05-30 15:48:27,812 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:27,812 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:27,820 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:27,820 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:48:27,913 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:27,913 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:27,997 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:28,005 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:28,113 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:28,121 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:28,121 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:28,130 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:28,213 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:28,213 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:28,221 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:28,221 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:28,230 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:28,230 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:28,238 - build_training_set - INFO - 📅 Date range: 2025-01-01 00:00:00+00:00 → 2025-03-22 00:00:00+00:00
# 2025-05-30 15:48:28,239 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:28,247 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:28,329 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:28,333 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:28,788 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-16 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:28,789 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:28,789 - build_training_set - INFO - 🧠 Actuals van 2025-01-02 00:00:00+00:00 t/m 2025-03-15 23:00:00+00:00 (extended to 2025-03-16 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:28,789 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-16 00:00:00+00:00, normalized to 2025-03-16 00:00:00+00:00 for DB lookup, target range: 2025-03-16 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 15:48:28,791 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:28,798 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:28,799 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:28,871 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:28,871 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:28,889 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:28,895 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:28,913 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:28,920 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:28,920 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:28,922 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:28,922 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 1: ✅ 144 test rows, Run: 03-15
# 2025-05-30 15:48:29,003 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:29,003 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:29,100 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:29,100 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:29,297 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:29,299 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:29,301 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:29,306 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:29,354 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:29,354 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:29,354 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:29,365 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:29,365 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:29,365 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:29,365 - build_training_set - INFO - 📅 Date range: 2025-01-02 00:00:00+00:00 → 2025-03-23 00:00:00+00:00
# 2025-05-30 15:48:29,365 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:29,375 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:29,422 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:29,431 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:29,624 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-17 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:29,625 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:29,625 - build_training_set - INFO - 🧠 Actuals van 2025-01-03 00:00:00+00:00 t/m 2025-03-16 23:00:00+00:00 (extended to 2025-03-17 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:29,625 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-17 00:00:00+00:00, normalized to 2025-03-17 00:00:00+00:00 for DB lookup, target range: 2025-03-17 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 15:48:29,629 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:29,630 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:29,633 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:29,686 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:29,696 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:29,716 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:29,716 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:29,734 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:29,742 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:29,742 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:29,749 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:29,749 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:48:29,814 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 2: ✅ 144 test rows, Run: 03-16
# 2025-05-30 15:48:29,822 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:29,947 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:29,947 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:30,099 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:30,107 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:30,107 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:30,115 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:30,189 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:30,197 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:30,201 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:30,210 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:30,215 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:30,215 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:30,215 - build_training_set - INFO - 📅 Date range: 2025-01-03 00:00:00+00:00 → 2025-03-24 00:00:00+00:00
# 2025-05-30 15:48:30,215 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:30,230 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:30,306 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:30,306 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:30,547 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-18 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:30,547 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:30,547 - build_training_set - INFO - 🧠 Actuals van 2025-01-04 00:00:00+00:00 t/m 2025-03-17 23:00:00+00:00 (extended to 2025-03-18 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:30,547 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-18 00:00:00+00:00, normalized to 2025-03-18 00:00:00+00:00 for DB lookup, target range: 2025-03-18 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 15:48:30,551 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:30,553 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:30,553 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:30,614 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:30,614 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:30,633 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:30,641 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:30,654 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:30,662 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:30,664 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:30,666 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:30,666 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 3: ✅ 144 test rows, Run: 03-17
# 2025-05-30 15:48:30,737 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:30,737 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:30,865 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:30,868 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:30,982 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:30,982 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:30,982 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:30,990 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:31,064 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:31,073 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:31,073 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:31,083 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:31,083 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:31,091 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:31,091 - build_training_set - INFO - 📅 Date range: 2025-01-04 00:00:00+00:00 → 2025-03-25 00:00:00+00:00
# 2025-05-30 15:48:31,099 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:31,110 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:31,192 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:31,192 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:31,425 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-19 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:31,425 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:31,425 - build_training_set - INFO - 🧠 Actuals van 2025-01-05 00:00:00+00:00 t/m 2025-03-18 23:00:00+00:00 (extended to 2025-03-19 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:31,425 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-19 00:00:00+00:00, normalized to 2025-03-19 00:00:00+00:00 for DB lookup, target range: 2025-03-19 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 15:48:31,432 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:31,435 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:31,435 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:31,499 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:31,499 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:31,516 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:31,524 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:31,539 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:31,539 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:31,539 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:31,547 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:31,549 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:48:31,615 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 4: ✅ 144 test rows, Run: 03-18
# 2025-05-30 15:48:31,615 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:31,689 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:31,689 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:31,797 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:31,806 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:31,806 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:31,815 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:31,882 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:31,882 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:31,882 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:31,890 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:31,901 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:31,901 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:31,901 - build_training_set - INFO - 📅 Date range: 2025-01-05 00:00:00+00:00 → 2025-03-26 00:00:00+00:00
# 2025-05-30 15:48:31,909 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:31,917 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:31,999 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:31,999 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:32,230 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-20 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:32,232 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:32,233 - build_training_set - INFO - 🧠 Actuals van 2025-01-06 00:00:00+00:00 t/m 2025-03-19 23:00:00+00:00 (extended to 2025-03-20 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:32,233 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-20 00:00:00+00:00, normalized to 2025-03-20 00:00:00+00:00 for DB lookup, target range: 2025-03-20 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 15:48:32,233 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:32,233 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:32,233 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:32,302 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:32,302 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:32,322 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:32,324 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:32,342 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:32,342 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:32,342 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:32,347 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:32,347 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 5: ✅ 144 test rows, Run: 03-19
# 2025-05-30 15:48:32,432 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:32,432 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:32,540 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:32,550 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:32,656 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:32,656 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:32,663 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:32,668 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:32,732 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:32,735 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:32,735 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:32,743 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:32,750 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:32,753 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:32,753 - build_training_set - INFO - 📅 Date range: 2025-01-06 00:00:00+00:00 → 2025-03-27 00:00:00+00:00
# 2025-05-30 15:48:32,753 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:32,767 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:32,853 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:32,853 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:33,066 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-21 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:33,066 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:33,066 - build_training_set - INFO - 🧠 Actuals van 2025-01-07 00:00:00+00:00 t/m 2025-03-20 23:00:00+00:00 (extended to 2025-03-21 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:33,066 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-21 00:00:00+00:00, normalized to 2025-03-21 00:00:00+00:00 for DB lookup, target range: 2025-03-21 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 15:48:33,066 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:33,074 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:33,074 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:33,137 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:33,137 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:33,157 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:33,167 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:33,184 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:33,184 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:33,192 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:33,192 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:33,192 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 6: ✅ 144 test rows, Run: 03-20
# 2025-05-30 15:48:33,290 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:33,298 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:33,433 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:33,441 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:33,508 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:33,516 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:33,516 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:33,524 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:33,584 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:33,592 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:33,592 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:33,600 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:33,600 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:33,608 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:33,608 - build_training_set - INFO - 📅 Date range: 2025-01-07 00:00:00+00:00 → 2025-03-28 00:00:00+00:00
# 2025-05-30 15:48:33,616 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:33,624 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:33,785 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:33,785 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:33,983 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-22 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:33,983 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:33,983 - build_training_set - INFO - 🧠 Actuals van 2025-01-08 00:00:00+00:00 t/m 2025-03-21 23:00:00+00:00 (extended to 2025-03-22 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:33,983 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-22 00:00:00+00:00, normalized to 2025-03-22 00:00:00+00:00 for DB lookup, target range: 2025-03-22 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 15:48:33,983 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:33,991 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:33,993 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:34,053 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:34,053 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:34,073 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:34,073 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:34,091 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:34,091 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:34,100 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:34,103 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:34,105 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 7: ✅ 144 test rows, Run: 03-21
# 2025-05-30 15:48:34,199 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:34,208 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:34,326 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:34,326 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:34,383 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:34,383 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:34,392 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:34,393 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:34,460 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:34,468 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:34,468 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:34,476 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:34,476 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:34,476 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:34,486 - build_training_set - INFO - 📅 Date range: 2025-01-08 00:00:00+00:00 → 2025-03-29 00:00:00+00:00
# 2025-05-30 15:48:34,486 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:34,494 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:34,581 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:34,587 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:34,801 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-23 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:34,801 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:34,801 - build_training_set - INFO - 🧠 Actuals van 2025-01-09 00:00:00+00:00 t/m 2025-03-22 23:00:00+00:00 (extended to 2025-03-23 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:34,801 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-23 00:00:00+00:00, normalized to 2025-03-23 00:00:00+00:00 for DB lookup, target range: 2025-03-23 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 15:48:34,808 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:34,810 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:34,810 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:34,878 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:34,880 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:34,902 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:34,902 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:34,920 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:34,920 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:34,928 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:34,928 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:34,928 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:48:35,001 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 8: ✅ 144 test rows, Run: 03-22
# 2025-05-30 15:48:35,001 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:35,100 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:35,102 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:35,239 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:35,239 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:35,239 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:35,251 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:35,309 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:35,309 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:35,318 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:35,318 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:35,326 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:35,326 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:35,326 - build_training_set - INFO - 📅 Date range: 2025-01-09 00:00:00+00:00 → 2025-03-30 00:00:00+00:00
# 2025-05-30 15:48:35,326 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:35,335 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:35,418 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:35,426 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:35,653 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-24 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:35,653 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:35,653 - build_training_set - INFO - 🧠 Actuals van 2025-01-10 00:00:00+00:00 t/m 2025-03-23 23:00:00+00:00 (extended to 2025-03-24 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:35,653 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-24 00:00:00+00:00, normalized to 2025-03-24 00:00:00+00:00 for DB lookup, target range: 2025-03-24 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 15:48:35,653 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:35,661 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:35,662 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:35,732 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:35,736 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:35,753 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:35,761 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:35,792 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:35,792 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:35,792 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:35,801 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:35,802 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 9: ✅ 144 test rows, Run: 03-23
# 2025-05-30 15:48:35,895 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:35,895 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:36,027 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:36,027 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:36,144 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:36,154 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:36,154 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:36,169 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:36,236 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:36,236 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:36,245 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:36,253 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:36,253 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:36,253 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:36,262 - build_training_set - INFO - 📅 Date range: 2025-01-10 00:00:00+00:00 → 2025-03-31 00:00:00+00:00
# 2025-05-30 15:48:36,262 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:36,270 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:36,350 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:36,352 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:36,565 - build_training_set - INFO - 📅 Loading additional historical data until 2025-03-25 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:36,568 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:36,570 - build_training_set - INFO - 🧠 Actuals van 2025-01-11 00:00:00+00:00 t/m 2025-03-24 23:00:00+00:00 (extended to 2025-03-25 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:36,570 - build_training_set - INFO - 📅 Forecast van run_date 2025-03-25 00:00:00+00:00, normalized to 2025-03-25 00:00:00+00:00 for DB lookup, target range: 2025-03-25 00:00:00+00:00 → 2025-04-01 00:00:00+00:00
# 2025-05-30 15:48:36,572 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:36,575 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:36,575 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:36,694 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:36,702 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:36,720 - build_training_set - INFO - 📊 Forecast rows available: 169
# ...
# 2025-05-30 15:48:51,215 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:51,448 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-11 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:51,450 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:51,450 - build_training_set - INFO - 🧠 Actuals van 2025-01-28 00:00:00+00:00 t/m 2025-04-10 23:00:00+00:00 (extended to 2025-04-11 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:51,451 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-11 00:00:00+00:00, normalized to 2025-04-11 00:00:00+00:00 for DB lookup, target range: 2025-04-11 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 15:48:51,451 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:51,451 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:51,451 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:51,513 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:51,513 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:51,533 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:51,541 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:51,559 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:51,559 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:51,563 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:51,563 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:51,563 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 27: ✅ 144 test rows, Run: 04-10
# 2025-05-30 15:48:51,632 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:51,640 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:51,773 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:51,773 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:51,898 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:51,898 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:51,907 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:51,916 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:51,974 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:51,984 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:51,984 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:51,993 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:52,000 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:52,000 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:52,000 - build_training_set - INFO - 📅 Date range: 2025-01-28 00:00:00+00:00 → 2025-04-18 00:00:00+00:00
# 2025-05-30 15:48:52,008 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:52,020 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:52,104 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:52,109 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:52,317 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-12 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:52,325 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:52,326 - build_training_set - INFO - 🧠 Actuals van 2025-01-29 00:00:00+00:00 t/m 2025-04-11 23:00:00+00:00 (extended to 2025-04-12 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:52,326 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-12 00:00:00+00:00, normalized to 2025-04-12 00:00:00+00:00 for DB lookup, target range: 2025-04-12 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 15:48:52,327 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:52,332 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:52,332 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:52,396 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:52,398 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:52,418 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:52,418 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:52,449 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:52,449 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:52,457 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:52,457 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:52,457 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# Day 28: ✅ 144 test rows, Run: 04-11
# 2025-05-30 15:48:52,550 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# 2025-05-30 15:48:52,550 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:52,682 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:52,682 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:52,808 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:52,817 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:52,817 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:52,826 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:52,897 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:52,897 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:52,905 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:52,908 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:52,908 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:52,917 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:52,917 - build_training_set - INFO - 📅 Date range: 2025-01-29 00:00:00+00:00 → 2025-04-19 00:00:00+00:00
# 2025-05-30 15:48:52,917 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:52,931 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:52,997 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:52,999 - build_training_set - INFO - 🔒 Connection closed
# 2025-05-30 15:48:53,241 - build_training_set - INFO - 📅 Loading additional historical data until 2025-04-13 00:00:00+00:00 for lagging support
# 2025-05-30 15:48:53,243 - build_training_set - INFO - 🚀 Start build van trainingset
# 2025-05-30 15:48:53,243 - build_training_set - INFO - 🧠 Actuals van 2025-01-30 00:00:00+00:00 t/m 2025-04-12 23:00:00+00:00 (extended to 2025-04-13 00:00:00+00:00 for lagging)
# 2025-05-30 15:48:53,243 - build_training_set - INFO - 📅 Forecast van run_date 2025-04-13 00:00:00+00:00, normalized to 2025-04-13 00:00:00+00:00 for DB lookup, target range: 2025-04-13 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 15:48:53,243 - build_training_set - INFO - 📥 Loading actuals with selected columns only...
# 2025-05-30 15:48:53,251 - build_training_set - INFO - 📋 Requested columns found: 21/21
# 2025-05-30 15:48:53,251 - build_training_set - INFO - 📋 Using columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:53,317 - build_training_set - INFO - ✅ Actuals loaded: 1752 rows with 21 selected columns
# 2025-05-30 15:48:53,317 - build_training_set - INFO - 🔍 Loading forecast/prediction data...
# 2025-05-30 15:48:53,335 - build_training_set - INFO - 📊 Forecast rows available: 169
# 2025-05-30 15:48:53,335 - build_training_set - INFO - 📋 Common columns for predictions: 17 - ['target_datetime', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'yearday_cos', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:53,353 - build_training_set - INFO - ✅ Predictions loaded: 169 rows with 17 columns
# 2025-05-30 15:48:53,353 - build_training_set - INFO - 🔧 Missing columns in predictions: ['Price', 'Load', 'Flow_NO', 'Flow_GB']
# 2025-05-30 15:48:53,353 - build_training_set - INFO - 📊 Applying 168-hour lag for missing columns (excluding target variables)...
# 2025-05-30 15:48:53,361 - build_training_set - INFO -    🎯 Column 'Price' is target variable - filled with NaN (not lagged)
# 2025-05-30 15:48:53,361 - build_training_set - INFO -    🕐 Lagging column 'Load' by 168 hours
# 2025-05-30 15:48:53,453 - build_training_set - INFO -    ✅ Added Load: 169/169 values found
# Day 29: ✅ 144 test rows, Run: 04-12
# 2025-05-30 15:48:53,453 - build_training_set - INFO -    🕐 Lagging column 'Flow_NO' by 168 hours
# 2025-05-30 15:48:53,575 - build_training_set - INFO -    ✅ Added Flow_NO: 169/169 values found
# 2025-05-30 15:48:53,575 - build_training_set - INFO -    🕐 Lagging column 'Flow_GB' by 168 hours
# 2025-05-30 15:48:53,710 - build_training_set - INFO -    ✅ Added Flow_GB: 169/169 values found
# 2025-05-30 15:48:53,718 - build_training_set - INFO - 🔄 Combining actuals and predictions...
# 2025-05-30 15:48:53,718 - build_training_set - INFO - 💰 Retrieving actual prices for forecast period...
# 2025-05-30 15:48:53,726 - build_training_set - INFO - 📊 Found 169 actual prices for forecast period
# 2025-05-30 15:48:53,784 - build_training_set - INFO - ✅ Filled 169/169 prediction prices with actual values
# 2025-05-30 15:48:53,784 - build_training_set - INFO - 💰 Price coverage: 169/169 (100.0%)
# 2025-05-30 15:48:53,784 - build_training_set - INFO - ✅ Combined dataset: 1921 rows (1752 actuals + 169 predictions)
# 2025-05-30 15:48:53,792 - build_training_set - INFO - ✅ No overlap between actuals and predictions
# 2025-05-30 15:48:53,792 - build_training_set - INFO - 📦 Final combined table: 1921 rows, 21 columns
# 2025-05-30 15:48:53,792 - build_training_set - INFO - 🧾 Final columns: ['Price', 'target_datetime', 'Load', 'shortwave_radiation', 'temperature_2m', 'direct_normal_irradiance', 'diffuse_radiation', 'Flow_NO', 'yearday_cos', 'Flow_GB', 'month', 'is_dst', 'yearday_sin', 'wind_speed_10m', 'is_non_working_day', 'hour_cos', 'is_weekend', 'cloud_cover', 'weekday_sin', 'hour_sin', 'weekday_cos']
# 2025-05-30 15:48:53,792 - build_training_set - INFO - 📅 Date range: 2025-01-30 00:00:00+00:00 → 2025-04-20 00:00:00+00:00
# 2025-05-30 15:48:53,802 - build_training_set - INFO - 💰 Price NaN count: 0/1921 (0.0%)
# 2025-05-30 15:48:53,802 - build_training_set - INFO - ✅ All columns have good data quality (<20% NaN)
# 2025-05-30 15:48:53,874 - build_training_set - INFO - ✅ Saved as training_set in WARP.db
# 2025-05-30 15:48:53,874 - build_training_set - INFO - 🔒 Connection closed
# Day 30: ✅ 144 test rows, Run: 04-13
#
# 📊 OVERALL RMSE - XGBoost Model
# ================================================================================
# Successful runs: 30/30
#  iteration   run_date  valid_predictions  rmse
#          1 2025-03-15                144  0.04
#          2 2025-03-16                144  0.04
#          3 2025-03-17                144  0.04
#          4 2025-03-18                144  0.04
#          5 2025-03-19                144  0.04
#          6 2025-03-20                144  0.04
#          7 2025-03-21                144  0.04
#          8 2025-03-22                144  0.03
#          9 2025-03-23                144  0.03
#         10 2025-03-24                144  0.04
#         11 2025-03-25                144  0.04
#         12 2025-03-26                144  0.04
#         13 2025-03-27                144  0.05
#         14 2025-03-28                144  0.05
#         15 2025-03-29                144  0.05
#         16 2025-03-30                144  0.04
#         17 2025-03-31                144  0.04
#         18 2025-04-01                144  0.04
#         19 2025-04-02                144  0.03
#         20 2025-04-03                144  0.03
#         21 2025-04-04                144  0.03
#         22 2025-04-05                144  0.03
#         23 2025-04-06                144  0.03
#         24 2025-04-07                144  0.03
#         25 2025-04-08                144  0.02
#         26 2025-04-09                144  0.02
#         27 2025-04-10                144  0.02
#         28 2025-04-11                144  0.03
#         29 2025-04-12                144  0.03
#         30 2025-04-13                144  0.02
#
# 📈 SUMMARY STATISTICS
# ----------------------------------------
# count    30.00
# mean      0.04
# std       0.01
# min       0.02
# 25%       0.03
# 50%       0.04
# 75%       0.04
# max       0.05
# Name: rmse, dtype: float64
#
# 📊 AVERAGE OVERALL RMSE
# ----------------------------------------
# Mean RMSE: 0.0361
# Stddev RMSE: 0.0089
